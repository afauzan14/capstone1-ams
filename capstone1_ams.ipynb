# %% [markdown]
# <a href="https://colab.research.google.com/github/afauzan14/capstone1-ams/blob/main/capstone1_ams.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Kelompok B Final Project**
# | Nama | NIM | Kontribusi | Persentase |
# | -------- | -------- | -------- | -------- |
# | Baharuddin Syaefullah Asyubanji | 11220940000001| Presentator, Mencari insight | 100% |
# | Dani Hidayat  | 11220940000014| Penulis script code, Mencari insight | 100% |
# | Nadira Afsarina Biya | 11220940000021| Presentator, Mencari insight | 100% |
# | Ahmad Fauzan | 11220940000031| Penulis script code, Mencari insight | 100% |
# | Kiara Zerlin Windriyani | 11220940000038| Presentator, Mencari insight | 100% |

# %%
# !pip install squarify
# !pip install Sastrawi
# !pip install unidecode

import torch
import itertools, re, pickle
import time, operator, numpy as np, matplotlib.pyplot as plt, pandas as pd, seaborn as sns
import networkx as nx
import squarify
import plotly.express as px
import plotly.graph_objects as go
import matplotlib.colors as mcolors
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')

from nltk.tokenize import word_tokenize
from matplotlib.colors import ListedColormap
from textblob import TextBlob
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from unidecode import unidecode
from nltk.tag import CRFTagger
from html import unescape
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from tqdm import tqdm
from wordcloud import WordCloud

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"\nUsing device: {device}")

"DONE!!!"
# Out:
# Collecting squarify
#   Downloading squarify-0.4.4-py3-none-any.whl.metadata (600 bytes)
# Downloading squarify-0.4.4-py3-none-any.whl (4.1 kB)
# Installing collected packages: squarify
# Successfully installed squarify-0.4.4
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl.metadata (909 bytes)
# Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 5.8 MB/s eta 0:00:00
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1
# Collecting unidecode
#   Downloading Unidecode-1.4.0-py3-none-any.whl.metadata (13 kB)
# Downloading Unidecode-1.4.0-py3-none-any.whl (235 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.8/235.8 kB 4.7 MB/s eta 0:00:00
# Installing collected packages: unidecode
# Successfully installed unidecode-1.4.0
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# 'DONE!!!'

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/afauzan14/capstone1-ams/main/tiktok-ams-capstone1.csv")
df
# Out:
#                                         avatarThumbnail                  cid  \
# 0     https://p16-common-sign-sg.tiktokcdn-us.com/to...  7509100558436762375
# 1     https://p16-common-sign-sg.tiktokcdn-us.com/to...  7506044062333944584
# 2     https://p16-common-sign-sg.tiktokcdn-us.com/to...  7508994709831172885
# 3     https://p16-common-sign-va.tiktokcdn-us.com/to...  7506056415371756306
# 4     https://p16-common-sign-sg.tiktokcdn-us.com/to...  7506044081106141960
# ...                                                 ...                  ...
# 5962  https://p16-common-sign-sg.tiktokcdn-us.com/to...  7505355215265284871
# 5963  https://p16-common-sign-va.tiktokcdn-us.com/to...  7505328346152518418
# 5964  https://p16-common-sign-sg.tiktokcdn-us.com/to...  7505328297192129298
# 5965  https://p16-common-sign-sg.tiktokcdn-us.com/to...  7505321197568623368
# 5966  https://p16-common-sign-sg.tiktokcdn-us.com/to...  7505308708680057621
#
#       createTime             createTimeISO  diggCount  \
# 0     1748348727  2025-05-27T12:25:27.000Z          0
# 1     1747637093  2025-05-19T06:44:53.000Z          6
# 2     1748324080  2025-05-27T05:34:40.000Z          0
# 3     1747639961  2025-05-19T07:32:41.000Z          9
# 4     1747637087  2025-05-19T06:44:47.000Z         19
# ...          ...                       ...        ...
# 5962  1747476693  2025-05-17T10:11:33.000Z          0
# 5963  1747470450  2025-05-17T08:27:30.000Z          0
# 5964  1747470440  2025-05-17T08:27:20.000Z          0
# 5965  1747468782  2025-05-17T07:59:42.000Z          0
# 5966  1747465871  2025-05-17T07:11:11.000Z          0
#
#                                                   input  likedByAuthor  \
# 0     https://www.tiktok.com/@sctv_/video/7506043543...          False
# 1     https://www.tiktok.com/@sctv_/video/7506043543...          False
# 2     https://www.tiktok.com/@sctv_/video/7506043543...          False
# 3     https://www.tiktok.com/@sctv_/video/7506043543...          False
# 4     https://www.tiktok.com/@sctv_/video/7506043543...          False
# ...                                                 ...            ...
# 5962  https://www.tiktok.com/@leo_giovannii/video/75...          False
# 5963  https://www.tiktok.com/@leo_giovannii/video/75...          False
# 5964  https://www.tiktok.com/@leo_giovannii/video/75...          False
# 5965  https://www.tiktok.com/@leo_giovannii/video/75...          False
# 5966  https://www.tiktok.com/@leo_giovannii/video/75...          False
#
#      pinnedByAuthor  repliesToId  replyCommentTotal  \
# 0             False          NaN                0.0
# 1             False          NaN                0.0
# 2             False          NaN                0.0
# 3             False          NaN                5.0
# 4             False          NaN                0.0
# ...             ...          ...                ...
# 5962          False          NaN                0.0
# 5963          False          NaN                0.0
# 5964          False          NaN                0.0
# 5965          False          NaN                0.0
# 5966          False          NaN                0.0
#
#                                       submittedVideoUrl                  uid  \
# 0     https://www.tiktok.com/@sctv_/video/7506043543...  7446197017703203847
# 1     https://www.tiktok.com/@sctv_/video/7506043543...  6542820956922068994
# 2     https://www.tiktok.com/@sctv_/video/7506043543...  6958675421827433478
# 3     https://www.tiktok.com/@sctv_/video/7506043543...  6781287782930646018
# 4     https://www.tiktok.com/@sctv_/video/7506043543...  6780885067134190594
# ...                                                 ...                  ...
# 5962  https://www.tiktok.com/@leo_giovannii/video/75...  7080103343620539394
# 5963  https://www.tiktok.com/@leo_giovannii/video/75...  6547738613940781058
# 5964  https://www.tiktok.com/@leo_giovannii/video/75...  7501487753533293575
# 5965  https://www.tiktok.com/@leo_giovannii/video/75...  6861824855717921793
# 5966  https://www.tiktok.com/@leo_giovannii/video/75...  7495432604566062097
#
#                   uniqueId                                        videoWebUrl  \
# 0            joula.rantung  https://www.tiktok.com/@sctv_/video/7506043543...
# 1                 artica73  https://www.tiktok.com/@sctv_/video/7506043543...
# 2                  rnw1267  https://www.tiktok.com/@sctv_/video/7506043543...
# 3           secretlifeofil  https://www.tiktok.com/@sctv_/video/7506043543...
# 4              intanurhlza  https://www.tiktok.com/@sctv_/video/7506043543...
# ...                    ...                                                ...
# 5962  racunskincaremurce05  https://www.tiktok.com/@leo_giovannii/video/75...
# 5963            masitha_nm  https://www.tiktok.com/@leo_giovannii/video/75...
# 5964             maya.al88  https://www.tiktok.com/@leo_giovannii/video/75...
# 5965         milianlestari  https://www.tiktok.com/@leo_giovannii/video/75...
# 5966           yudi_store0  https://www.tiktok.com/@leo_giovannii/video/75...
#
#                                          text  \
# 0     🤣🤣🤣🤣🤣🤣 maybe we must ask ongkor in here
# 1                         min trailer agz min
# 2                                      omegot
# 3                            trailer agz min🥰
# 4                     trailer agz mana minnnn
# ...                                       ...
# 5962                  peraturan apa lgi inii😅
# 5963       pemerintah dg segala gebrakannya😭🤏
# 5964                       berita baru ini.kk
# 5965                                    keren
# 5966  back semua affiliate sini gercep guyss✅
#
#       Label (1 = positif, 2 = netral, 3 = negatif)
# 0                                                3
# 1                                                2
# 2                                                2
# 3                                                2
# 4                                                2
# ...                                            ...
# 5962                                             3
# 5963                                             3
# 5964                                             2
# 5965                                             1
# 5966                                             2
#
# [5967 rows x 16 columns]

# %%
df['Label (1 = positif, 2 = netral, 3 = negatif)'].value_counts()
# Out:
# Label (1 = positif, 2 = netral, 3 = negatif)
# 3    3154
# 2    2449
# 1     364
# Name: count, dtype: int64

# %%
df = df.rename(columns={'Label (1 = positif, 2 = netral, 3 = negatif)': 'label'})

# %%
df_text = df[['label', 'text']]
df_text
# Out:
#       label                                     text
# 0         3  🤣🤣🤣🤣🤣🤣 maybe we must ask ongkor in here
# 1         2                      min trailer agz min
# 2         2                                   omegot
# 3         2                         trailer agz min🥰
# 4         2                  trailer agz mana minnnn
# ...     ...                                      ...
# 5962      3                  peraturan apa lgi inii😅
# 5963      3       pemerintah dg segala gebrakannya😭🤏
# 5964      2                       berita baru ini.kk
# 5965      1                                    keren
# 5966      2  back semua affiliate sini gercep guyss✅
#
# [5967 rows x 2 columns]

# %%
df_text.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5967 entries, 0 to 5966
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   label   5967 non-null   int64
#  1   text    5967 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 93.4+ KB

# %%
df_text['label'] = df_text['label'].astype('category')
# Out:
# <ipython-input-8-46ee6df4db99>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_text['label'] = df_text['label'].astype('category')

# %%
df_text.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5967 entries, 0 to 5966
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   label   5967 non-null   category
#  1   text    5967 non-null   object
# dtypes: category(1), object(1)
# memory usage: 52.7+ KB

# %%
def remove_URL(tweet): # Menghapus URL
    url = re.compile(r'https?://\S+|www\.\S+')
    return url.sub(r'', tweet)

def remove_html(tweet): # Menghapus tag HTML
    html = re.compile(r'<.*?>')
    return html.sub(r'', tweet)

def remove_emoji(tweet): # Menghapus emoji
    emoji_pattern = re.compile("["
        u"\U0001F600-\U0001F64F"
        u"\U0001F300-\U0001F5FF"
        u"\U0001F680-\U0001F6FF"
        u"\U0001F1E0-\U0001F1FF"
                            "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', tweet)

def remove_username(tweet): # Menghapus username
    username_pattern = re.compile(r'@\w+')
    return username_pattern.sub(r'', tweet)

def remove_numbers (tweet): # Menghapus angka
    tweet = re.sub(r'\d+', '', tweet)
    return tweet

def remove_symbols (tweet): # Menghapus simbol
    tweet = re.sub(r'[^a-zA-Z0-9\s]', '', tweet)
    return tweet

def case_folding(text): # Mengubah huruf yang masih uppercase menjadi lowercase
  if isinstance(text, str):
    lowercase_text = text.lower()
    return lowercase_text
  else:
    return text

# %%
# Visualisasi clean dataset 'full_text'
df_text['cleaning'] = df_text['text'].apply(lambda x: remove_URL(x))
df_text['cleaning'] = df_text['cleaning'].apply(lambda x: remove_html(x))
df_text['cleaning'] = df_text['cleaning'].apply(lambda x: remove_emoji(x))
df_text['cleaning'] = df_text['cleaning'].apply(lambda x: remove_username(x))
df_text['cleaning'] = df_text['cleaning'].apply(lambda x: remove_symbols(x))
df_text['cleaning'] = df_text['cleaning'].apply(lambda x: remove_numbers(x))
df_text['cleaning'] = df_text['cleaning'].apply(lambda x: case_folding(x))

df_text
# Out:
# <ipython-input-11-11b15b140ea4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_text['cleaning'] = df_text['text'].apply(lambda x: remove_URL(x))
# <ipython-input-11-11b15b140ea4>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_text['cleaning'] = df_text['cleaning'].apply(lambda x: remove_html(x))
# <ipython-input-11-11b15b140ea4>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_text['cleaning'] = df_text['cleaning'].apply(lambda x: remove_emoji(x))
# <ipython-input-11-11b15b140ea4>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_text['cleaning'] = df_text['cleaning'].apply(lambda x: remove_username(x))
# <ipython-input-11-11b15b140ea4>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_text['cleaning'] = df_text['cleaning'].apply(lambda x: remove_symbols(x))
# <ipython-input-11-11b15b140ea4>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_text['cleaning'] = df_text['cleaning'].apply(lambda x: remove_numbers(x))
# <ipython-input-11-11b15b140ea4>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_text['cleaning'] = df_text['cleaning'].apply(lambda x: case_folding(x))
#      label                                     text  \
# 0        3  🤣🤣🤣🤣🤣🤣 maybe we must ask ongkor in here
# 1        2                      min trailer agz min
# 2        2                                   omegot
# 3        2                         trailer agz min🥰
# 4        2                  trailer agz mana minnnn
# ...    ...                                      ...
# 5962     3                  peraturan apa lgi inii😅
# 5963     3       pemerintah dg segala gebrakannya😭🤏
# 5964     2                       berita baru ini.kk
# 5965     1                                    keren
# 5966     2  back semua affiliate sini gercep guyss✅
#
#                                     cleaning
# 0           maybe we must ask ongkor in here
# 1                        min trailer agz min
# 2                                     omegot
# 3                            trailer agz min
# 4                    trailer agz mana minnnn
# ...                                      ...
# 5962                  peraturan apa lgi inii
# 5963        pemerintah dg segala gebrakannya
# 5964                       berita baru inikk
# 5965                                   keren
# 5966  back semua affiliate sini gercep guyss
#
# [5967 rows x 3 columns]

# %%
df_text['cleaning'].duplicated().sum()
# Out:
# np.int64(472)

# %%
df_text[df_text['cleaning'].duplicated(keep='first')]
# Out:
#      label                                               text  \
# 67       2                                            betulll
# 81       2                                            betulll
# 161      2                    mending up trailer agz aja min😌
# 217      3  @putri:sibuk banget pemerintah ngurusin hal be...
# 291      3                   seneng banget bikin susah rakyat
# ...    ...                                                ...
# 5930     2                           sini aku back semua 🔥🔥🔥🔥
# 5944     2                                            pertama
# 5949     1                                             setuju
# 5954     1                                            Mantap🔥
# 5960     3                                sedih susah belanja
#
#                                             cleaning
# 67                                           betulll
# 81                                           betulll
# 161                   mending up trailer agz aja min
# 217   sibuk banget pemerintah ngurusin hal beginian
# 291                 seneng banget bikin susah rakyat
# ...                                              ...
# 5930                            sini aku back semua
# 5944                                         pertama
# 5949                                          setuju
# 5954                                          mantap
# 5960                             sedih susah belanja
#
# [472 rows x 3 columns]

# %%
df_text = df_text.drop_duplicates(subset='cleaning', keep='first')
df_text
# Out:
#      label                                     text  \
# 0        3  🤣🤣🤣🤣🤣🤣 maybe we must ask ongkor in here
# 1        2                      min trailer agz min
# 2        2                                   omegot
# 3        2                         trailer agz min🥰
# 4        2                  trailer agz mana minnnn
# ...    ...                                      ...
# 5962     3                  peraturan apa lgi inii😅
# 5963     3       pemerintah dg segala gebrakannya😭🤏
# 5964     2                       berita baru ini.kk
# 5965     1                                    keren
# 5966     2  back semua affiliate sini gercep guyss✅
#
#                                     cleaning
# 0           maybe we must ask ongkor in here
# 1                        min trailer agz min
# 2                                     omegot
# 3                            trailer agz min
# 4                    trailer agz mana minnnn
# ...                                      ...
# 5962                  peraturan apa lgi inii
# 5963        pemerintah dg segala gebrakannya
# 5964                       berita baru inikk
# 5965                                   keren
# 5966  back semua affiliate sini gercep guyss
#
# [5495 rows x 3 columns]

# %%
df_text.reset_index(inplace=True, drop=True)
df_text
# Out:
#      label                                     text  \
# 0        3  🤣🤣🤣🤣🤣🤣 maybe we must ask ongkor in here
# 1        2                      min trailer agz min
# 2        2                                   omegot
# 3        2                         trailer agz min🥰
# 4        2                  trailer agz mana minnnn
# ...    ...                                      ...
# 5490     3                  peraturan apa lgi inii😅
# 5491     3       pemerintah dg segala gebrakannya😭🤏
# 5492     2                       berita baru ini.kk
# 5493     1                                    keren
# 5494     2  back semua affiliate sini gercep guyss✅
#
#                                     cleaning
# 0           maybe we must ask ongkor in here
# 1                        min trailer agz min
# 2                                     omegot
# 3                            trailer agz min
# 4                    trailer agz mana minnnn
# ...                                      ...
# 5490                  peraturan apa lgi inii
# 5491        pemerintah dg segala gebrakannya
# 5492                       berita baru inikk
# 5493                                   keren
# 5494  back semua affiliate sini gercep guyss
#
# [5495 rows x 3 columns]

# %%
df_text.sample(10)
# Out:
#      label                                               text  \
# 1365     2            malah aku mah dlebihin terus dksh LG kk
# 574      2                                         @Afiyati N
# 1771     2                                            iy lg..
# 1932     2    biar apa ???? biar buibu tidak co terosshhhh😜😜😜
# 432      2  iya sama kak klo cod suka di kasih lebihnya so...
# 2680     2  Itu emng ad biaya penanganan skitar 1500 biasa...
# 3399     3                    capek bgt sm pemerintahan ini 😭
# 2899     3                                       sy keberatan
# 2024     2  gak masalah ...aku kadang malah klu cod aku le...
# 1332     2  sama dsni sering banget bgtu, udh muak banget....
#
#                                                cleaning
# 1365            malah aku mah dlebihin terus dksh lg kk
# 574                                                   n
# 1771                                              iy lg
# 1932           biar apa  biar buibu tidak co terosshhhh
# 432   iya sama kak klo cod suka di kasih lebihnya so...
# 2680      itu emng ad biaya penanganan skitar  biasa ny
# 3399                     capek bgt sm pemerintahan ini
# 2899                                       sy keberatan
# 2024  gak masalah aku kadang malah klu cod aku lebih...
# 1332  sama dsni sering banget bgtu udh muak banget m...

# %% [markdown]
# # Slang

# %%
# !mkdir data
# !wget -P data/ https://raw.githubusercontent.com/afauzan14/capstone1-ams/main/slang_GratisOngkir.txt
# Out:
# --2025-06-05 06:46:26--  https://raw.githubusercontent.com/afauzan14/capstone1-ams/main/slang_GratisOngkir.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12652 (12K) [text/plain]
# Saving to: ‘data/slang_GratisOngkir.txt’
#
# slang_GratisOngkir. 100%[===================>]  12.36K  --.-KB/s    in 0.001s
#
# 2025-06-05 06:46:27 (22.1 MB/s) - ‘data/slang_GratisOngkir.txt’ saved [12652/12652]

# %%
# File slang
slang_file = 'data/slang_GratisOngkir.txt'

# Membuat kamus slang dari file
slang_dict = {}
with open(slang_file, 'r', encoding='utf-8') as file:
    for line in file:
        if ':' in line:
            slang, standard = line.strip().split(':', 1)
            slang_dict[slang.strip()] = standard.strip()

# Manual slang
manual_slang = {
    'omegot' : 'kaget',
    'maybe' : 'mungkin',
    'we' : 'kita',
    'must' : 'harus',
    'ask' : 'tanya',
    'in' : 'di',
    'here' : 'di sini',
    'minnnn' : 'admin',
    'gak' : 'tidak',
    'kalo' : 'kalau',
    'biarin' : 'biarkan',
    'biarlah' : 'biarkan',
    'kasi' : 'beri',
    'ku' : 'aku',
    'ga' : 'tidak',
    'bener' : 'benar',
    'jdi' : 'jadi',
    'sampe' : 'sampai',
    'pake' : 'pakai',
    'gue' : 'saya',
    'ongkirnya' : 'ongkir'
}

# Update kamus slang
slang_dict.update(manual_slang)
# ==========================================

# Fungsi untuk mengganti slang dengan kata baku
def normalize_slang(text):
    words = word_tokenize(text.lower())
    return ' '.join([slang_dict.get(word, word) for word in words])

# %%
# Terapkan normalisasi slang ke kolom 'cleaning'
df_text['normalized_comment'] = df_text['cleaning'].apply(normalize_slang)

# Tampilkan hasil
df_text
# Out:
# <ipython-input-19-5c5999013354>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_text['normalized_comment'] = df_text['cleaning'].apply(normalize_slang)
#      label                                     text  \
# 0        3  🤣🤣🤣🤣🤣🤣 maybe we must ask ongkor in here
# 1        2                      min trailer agz min
# 2        2                                   omegot
# 3        2                         trailer agz min🥰
# 4        2                  trailer agz mana minnnn
# ...    ...                                      ...
# 5490     3                  peraturan apa lgi inii😅
# 5491     3       pemerintah dg segala gebrakannya😭🤏
# 5492     2                       berita baru ini.kk
# 5493     1                                    keren
# 5494     2  back semua affiliate sini gercep guyss✅
#
#                                     cleaning  \
# 0           maybe we must ask ongkor in here
# 1                        min trailer agz min
# 2                                     omegot
# 3                            trailer agz min
# 4                    trailer agz mana minnnn
# ...                                      ...
# 5490                  peraturan apa lgi inii
# 5491        pemerintah dg segala gebrakannya
# 5492                       berita baru inikk
# 5493                                   keren
# 5494  back semua affiliate sini gercep guyss
#
#                               normalized_comment
# 0     mungkin kita harus tanya ongkir di di sini
# 1               admin trailer asmara gen z admin
# 2                                          kaget
# 3                     trailer asmara gen z admin
# 4                trailer asmara gen z mana admin
# ...                                          ...
# 5490                     peraturan apa lagi inii
# 5491        pemerintah dengan segala gebrakannya
# 5492                             berita baru ini
# 5493                                       keren
# 5494       back semua affiliate sini cepat guyss
#
# [5495 rows x 4 columns]

# %%
df_text.sample(10)
# Out:
#      label                                               text  \
# 4572     3  @NadyaDea @Rani @azka agrid @RivannoBintang @m...
# 629      3  walau gratis ongkir pun, saya suka kasih ongki...
# 2915     3  Bubarin aja dah ini negara. Gak ada gunanya pe...
# 2621     3                 siap2 sepi pembeli deh online shop
# 1743     2                       huft pantesaaaaan ga gratong
# 4419     3  kalau gratis ongkir dibatasi, pasti bakalan ja...
# 1441     2             1400 tidak akan membuatmu miskin cok..
# 5191     2                      Pingin sukses kaya koh Leo 🙏🙏
# 2668     3                           kurg krjaan biangt yaaa😂
# 596      2       Bener kak pernah kaya gini eh kurirnya marah
#
#                                                cleaning  \
# 4572        agrid   aku gabisa kalo ga gratis dan promo
# 629   walau gratis ongkir pun saya suka kasih ongkir...
# 2915  bubarin aja dah ini negara gak ada gunanya pem...
# 2621                  siap sepi pembeli deh online shop
# 1743                       huft pantesaaaaan ga gratong
# 4419  kalau gratis ongkir dibatasi pasti bakalan jar...
# 1441                    tidak akan membuatmu miskin cok
# 5191                        pingin sukses kaya koh leo
# 2668                            kurg krjaan biangt yaaa
# 596        bener kak pernah kaya gini eh kurirnya marah
#
#                                      normalized_comment
# 4572      agrid aku gabisa kalau tidak gratis dan promo
# 629   walau gratis ongkir pun saya suka kasih ongkir...
# 2915  bubarin saja dah ini negara tidak ada gunanya ...
# 2621               siap sepi pembeli deh online penjual
# 1743                     huft pantesaaaaan tidak ongkir
# 4419  kalau gratis ongkir dibatasi pasti bakalan jar...
# 1441                    tidak akan membuatmu miskin cok
# 5191                         pingin sukses kaya koh leo
# 2668                               kurg kerja biangt ya
# 596        benar kak pernah kaya gini eh kurirnya marah

# %% [markdown]
# # Stopword

# %%
# !wget -P data/ https://raw.githubusercontent.com/taudataanalytics/eLearning/refs/heads/master/data/stopwords_id.txt
# !wget -P data/ https://raw.githubusercontent.com/louisowen6/NLP_bahasa_resources/master/combined_stop_words.txt
# Out:
# --2025-06-05 06:46:28--  https://raw.githubusercontent.com/taudataanalytics/eLearning/refs/heads/master/data/stopwords_id.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6446 (6.3K) [text/plain]
# Saving to: ‘data/stopwords_id.txt’
#
# stopwords_id.txt    100%[===================>]   6.29K  --.-KB/s    in 0s
#
# 2025-06-05 06:46:28 (89.7 MB/s) - ‘data/stopwords_id.txt’ saved [6446/6446]
#
# --2025-06-05 06:46:28--  https://raw.githubusercontent.com/louisowen6/NLP_bahasa_resources/master/combined_stop_words.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6096 (6.0K) [text/plain]
# Saving to: ‘data/combined_stop_words.txt’
#
# combined_stop_words 100%[===================>]   5.95K  --.-KB/s    in 0s
#
# 2025-06-05 06:46:28 (64.5 MB/s) - ‘data/combined_stop_words.txt’ saved [6096/6096]

# %%
# Membaca file stopwords
stopword_files = ['data/stopwords_id.txt', 'data/combined_stop_words.txt']
id_stop = []
for stopword_file in stopword_files:
    with open(stopword_file, "r", encoding="utf-8", errors='replace') as file:
        id_stop.extend([word.strip().lower() for word in file.readlines()])


# Bersihkan stopwords (hapus spasi dan ubah ke huruf kecil)
id_stop = [word for word in id_stop if word] # remove empty strings

# %%
# dfWC = df_text.copy()
# dfWC

# %%
# Tambahkan stopwords tambahan
additional_stopwords = {'admin', 'mh', 'nya', 'iya', 'itu', 'kah', 'dan', 'ke', 'di',
                        'sih', 'coooyyyyy', 'sukak', 'syaaa', 'hehe', 'ongkos', 'ongkir',
                        'belanja', 'gratis', 'pakai', 'dengan', 'banget', 'orang', 'ini',
                        'guyss', 'z', 'kak', 'udah', 'nih', 'k', 'negara', 'dah', 'gin', 'mah', 'lebih', 'tuh',
                        'tau', 'deh', 'x', 'lg', 'kayak', 'karna', 'dpt', 'trus', 'gada', 'ka', 'manaaaaaaaaaaa',
                        'y', 'sm', 'tpi'}
id_stop.extend(additional_stopwords)  # Gabungkan stopwords tambahan

# Fungsi untuk menghapus stopwords
def remove_custom_stopwords(text):
    words = word_tokenize(text)  # Tokenisasi teks
    return ' '.join([word for word in words if word not in id_stop])

# %%
df_text['no_stop'] = df_text['normalized_comment'].apply(remove_custom_stopwords)
df_text
# Out:
# <ipython-input-25-2cdd5579c2d4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_text['no_stop'] = df_text['normalized_comment'].apply(remove_custom_stopwords)
#      label                                     text  \
# 0        3  🤣🤣🤣🤣🤣🤣 maybe we must ask ongkor in here
# 1        2                      min trailer agz min
# 2        2                                   omegot
# 3        2                         trailer agz min🥰
# 4        2                  trailer agz mana minnnn
# ...    ...                                      ...
# 5490     3                  peraturan apa lgi inii😅
# 5491     3       pemerintah dg segala gebrakannya😭🤏
# 5492     2                       berita baru ini.kk
# 5493     1                                    keren
# 5494     2  back semua affiliate sini gercep guyss✅
#
#                                     cleaning  \
# 0           maybe we must ask ongkor in here
# 1                        min trailer agz min
# 2                                     omegot
# 3                            trailer agz min
# 4                    trailer agz mana minnnn
# ...                                      ...
# 5490                  peraturan apa lgi inii
# 5491        pemerintah dg segala gebrakannya
# 5492                       berita baru inikk
# 5493                                   keren
# 5494  back semua affiliate sini gercep guyss
#
#                               normalized_comment                 no_stop
# 0     mungkin kita harus tanya ongkir di di sini
# 1               admin trailer asmara gen z admin      trailer asmara gen
# 2                                          kaget                   kaget
# 3                     trailer asmara gen z admin      trailer asmara gen
# 4                trailer asmara gen z mana admin      trailer asmara gen
# ...                                          ...                     ...
# 5490                     peraturan apa lagi inii          peraturan inii
# 5491        pemerintah dengan segala gebrakannya  pemerintah gebrakannya
# 5492                             berita baru ini                  berita
# 5493                                       keren                   keren
# 5494       back semua affiliate sini cepat guyss    back affiliate cepat
#
# [5495 rows x 5 columns]

# %%
# # Tambahkan stopwords tambahan
# additional_stopwords = {'admin', 'mh', 'nya', 'iya', 'itu', 'kah', 'dan', 'ke', 'di',
#                         'sih', 'coooyyyyy', 'sukak', 'syaaa', 'hehe', 'ongkos', 'ongkir',
#                         'pemerintah', 'belanja', 'online', 'gratis', 'pakai', 'dengan', 'banget', 'orang', 'ini',
#                         'guyss', 'z', 'kak', 'udah', 'nih', 'k', 'negara', 'dah', 'gin', 'mah', 'lebih', 'tuh',
#                         'tau', 'deh', 'x', 'lg', 'kayak', 'karna', 'dpt', 'trus', 'gada', 'ka', 'manaaaaaaaaaaa',
#                         'y', 'sm', 'tpi'}
# id_stop.extend(additional_stopwords)  # Gabungkan stopwords tambahan

# # Fungsi untuk menghapus stopwords
# def remove_custom_stopwords_WC(text):
#     words = word_tokenize(text)  # Tokenisasi teks
#     return ' '.join([word for word in words if word not in id_stop])

# %%
# dfWC['no_stopwords'] = dfWC['normalized_comment'].apply(remove_custom_stopwords_WC)
# dfWC

# %% [markdown]
# # Lemma

# %%
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# %%
# Daftar kata dasar manual
kata_dasar = ['setuju', 'sukses', 'terbaik', 'pemerataan', 'lingkungan', 'setara', 'alasan',
              'pendidikan', 'peserta', 'impian', 'kejuruan', 'menteri', 'terapkan', 'perdebatan',
              'hilangkan', 'biarkan', 'pemerintah']  # Tambahkan kata dasar manual lainnya

# %%
# Fungsi stemming dengan perlindungan kata dasar
def stem_text(text):
    words = text.split()
    stemmed_words = []
    for word in words:
        stemmed = stemmer.stem(word)
        # Jika kata asli ada di kata_dasar, gunakan kata asli
        if word in kata_dasar:
            stemmed_words.append(word)
        # Jika hasil stemming malah menghapus bentuk dasar yang kamu inginkan
        elif stemmed in kata_dasar:
            stemmed_words.append(stemmed)
        else:
            stemmed_words.append(stemmed)
    return ' '.join(stemmed_words)

# %%
# # Fungsi stemming menggunakan Sastrawi dengan pengecualian kata dasar manual
# def stem_text(text):
#     words = text.split()
#     stemmed_words = []
#     for word in words:
#         if word in kata_dasar:
#             stemmed_words.append(word)
#         else:
#             stemmed_words.append(stemmer.stem(word))
#     return ' '.join(stemmed_words)

# %%
# factory = StemmerFactory()
# stemmer = factory.create_stemmer()

# # Fungsi stemming menggunakan Sastrawi
# def stem_text(text):
#     return stemmer.stem(text)

# %%
# Terapkan stemming pada kolom 'no_stopwords'
df_text['stemmed_text'] = df_text['no_stop'].apply(stem_text)
# Out:
# <ipython-input-33-4533485130a4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_text['stemmed_text'] = df_text['no_stop'].apply(stem_text)

# %%
# # Terapkan stemming pada kolom 'no_stopwords'
# dfWC['no_stopwords'] = dfWC['no_stopwords'].apply(stem_text)
# # dfWC['stemmed_text'] = dfWC['no_stopwords'].apply(stem_text)

# %%
df_text
# Out:
#      label                                     text  \
# 0        3  🤣🤣🤣🤣🤣🤣 maybe we must ask ongkor in here
# 1        2                      min trailer agz min
# 2        2                                   omegot
# 3        2                         trailer agz min🥰
# 4        2                  trailer agz mana minnnn
# ...    ...                                      ...
# 5490     3                  peraturan apa lgi inii😅
# 5491     3       pemerintah dg segala gebrakannya😭🤏
# 5492     2                       berita baru ini.kk
# 5493     1                                    keren
# 5494     2  back semua affiliate sini gercep guyss✅
#
#                                     cleaning  \
# 0           maybe we must ask ongkor in here
# 1                        min trailer agz min
# 2                                     omegot
# 3                            trailer agz min
# 4                    trailer agz mana minnnn
# ...                                      ...
# 5490                  peraturan apa lgi inii
# 5491        pemerintah dg segala gebrakannya
# 5492                       berita baru inikk
# 5493                                   keren
# 5494  back semua affiliate sini gercep guyss
#
#                               normalized_comment                 no_stop  \
# 0     mungkin kita harus tanya ongkir di di sini
# 1               admin trailer asmara gen z admin      trailer asmara gen
# 2                                          kaget                   kaget
# 3                     trailer asmara gen z admin      trailer asmara gen
# 4                trailer asmara gen z mana admin      trailer asmara gen
# ...                                          ...                     ...
# 5490                     peraturan apa lagi inii          peraturan inii
# 5491        pemerintah dengan segala gebrakannya  pemerintah gebrakannya
# 5492                             berita baru ini                  berita
# 5493                                       keren                   keren
# 5494       back semua affiliate sini cepat guyss    back affiliate cepat
#
#               stemmed_text
# 0
# 1       trailer asmara gen
# 2                    kaget
# 3       trailer asmara gen
# 4       trailer asmara gen
# ...                    ...
# 5490              atur ini
# 5491     pemerintah gebrak
# 5492                berita
# 5493                 keren
# 5494  back affiliate cepat
#
# [5495 rows x 6 columns]

# %% [markdown]
# # **Insight**

# %% [markdown]
# ## **Distribusi Sentimen Publik**

# %%
import matplotlib.pyplot as plt
import pandas as pd # Ensure pandas is imported

# Assume df_text is your DataFrame.
# For example, if it NOW contains text labels:
# data = {'label': ['Negatif', 'Netral', 'Positif', 'Negatif', 'Negatif']}
# df_text = pd.DataFrame(data)
# Or, if it still contains numbers (the previous code should have worked, but let's ensure robustness):
# data = {'label': [3, 2, 1, 3, 3]}
# df_text = pd.DataFrame(data)


# 1. Define the colors for your desired text labels
#    Make sure these keys match exactly what's in sentimen_counts.index OR what numeric_to_text_mapping produces.
sentiment_colors = {'Positif': 'cyan', 'Negatif': 'red', 'Netral': 'gray'}

# 2. Define the mapping from numeric labels to text labels
#    This will be used IF your data contains numbers.
numeric_to_text_mapping = {1: 'Positif', 2: 'Netral', 3: 'Negatif'}

# 3. Calculate sentiment counts
sentimen_counts = df_text['label'].value_counts()

# 4. Prepare the labels and corresponding colors for the pie chart
final_pie_labels = []
final_pie_colors = []

for label_in_data in sentimen_counts.index:
    text_label = ''
    if isinstance(label_in_data, (int, float)): # Check if the label from data is a number
        text_label = numeric_to_text_mapping.get(label_in_data, str(label_in_data)) # Convert number to text
    else: # If it's already text (like 'Negatif')
        text_label = str(label_in_data)

    final_pie_labels.append(text_label)
    # Get the color for this text label; use a default if not found to prevent KeyErrors
    final_pie_colors.append(sentiment_colors.get(text_label, 'lightgrey'))


# 5. Plot the pie chart
plt.figure(figsize=(6, 6))
plt.pie(
    sentimen_counts.values, # The actual count values
    labels=final_pie_labels, # The processed text labels
    autopct='%1.0f%%',
    startangle=90,
    wedgeprops={'linewidth': 2, 'edgecolor': 'white'},
    colors=final_pie_colors # The corresponding colors for the text labels
)
plt.title('Distribusi Sentimen (%)')
plt.show()

# %% [markdown]
# ### **Interpretasi Visualisasi:**
#
# - **Mayoritas Sentimen Negatif (55%):** Lebih dari separuh masyarakat (55%) menunjukkan sentimen negatif terhadap aturan pembatasan gratis ongkir. Ini kemungkinan besar karena bisa berdampak pada daya beli masyarakat, terutama di daerah dengan ongkir tinggi.
#
# - **Sentimen Netral Signifikan (38%):** Sekitar 38% masyarakat bersikap netral. Ini bisa berarti masyarakat belum paham sepenuhnya tentang aturan ini atau merasa aturan ini tidak terlalu memengaruhi mereka secara langsung.
#
# - **Sentimen Positif Minim (6%):** Hanya 6% yang menunjukkan sentimen positif. Ini mungkin mencerminkan sebagian kecil masyarakat, seperti pelaku usaha logistik atau kurir, yang merasa diuntungkan karena aturan ini melindungi kesejahteraan kurir dan mendorong persaingan sehat.

# %% [markdown]
# ## Analisis Sentimen Publik

# %%
# Buat DataFrame baru untuk label positif dan negatif
df_positif = df_text[df_text['label'] == 1]
df_netral = df_text[df_text['label'] == 2]
df_negatif = df_text[df_text['label'] == 3]

# %% [markdown]
# ### Sentimen Positif

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
import networkx as nx
import matplotlib.pyplot as plt

# Ambil teks komentar dengan label i
# Pastikan df_positif sudah terdefinisi sebelumnya, contoh:
# df_positif = pd.DataFrame({'stemmed_text': ['contoh teks satu', 'teks contoh dua', 'kalimat ketiga contoh']})
texts = df_positif['stemmed_text'].astype(str).str.lower().tolist()

# Gunakan CountVectorizer untuk bigram
vectorizer = CountVectorizer(ngram_range=(2, 2), min_df=2)
X = vectorizer.fit_transform(texts)
bigrams = vectorizer.get_feature_names_out()
counts = X.toarray().sum(axis=0)

# Gabungkan bigram dan frekuensinya
bigram_freq = list(zip(bigrams, counts))
bigram_freq_sorted = sorted(bigram_freq, key=lambda x: x[1], reverse=True)

# Ambil 50 bigram teratas (ubah jumlah sesuai kebutuhan)
top_n = 100
top_bigrams = [b[0] for b in bigram_freq_sorted[:top_n]]
edges = [tuple(b.split()) for b in top_bigrams]

# Buat graph dari bigram
G1 = nx.Graph()
G1.add_edges_from(edges)

# Hitung derajat setiap node
degrees = [G1.degree(node) for node in G1.nodes()]

# Tentukan faktor skala untuk ukuran node (sesuaikan sesuai kebutuhan)
scale_factor = 200

# Sesuaikan ukuran node berdasarkan derajatnya
node_sizes = [degree * scale_factor for degree in degrees]

# Visualisasi
plt.figure(figsize=(14, 10))
pos = nx.spring_layout(G1, k=0.6, seed=42) # k mengatur jarak antar node
nx.draw(
    G1, pos,
    with_labels=True,
    node_color='lightblue',
    edge_color='gray',
    node_size=node_sizes, # Gunakan ukuran node yang sudah disesuaikan
    font_size=10,
    font_weight='bold'
)
plt.title(f"Top {top_n} Word Link (Bigram Network) dari sentimen positif (Ukuran Node Berdasarkan Derajat)", fontsize=16)
plt.show()

# %%
# Cek kata apa yang paling banyak punya edge (koneksi).
import networkx as nx

centrality = nx.degree_centrality(G1)
sorted(centrality.items(), key=lambda x: x[1], reverse=True)[:10]
# Out:
# [('biar', 0.22058823529411764),
#  ('kurir', 0.20588235294117646),
#  ('offline', 0.16176470588235295),
#  ('paket', 0.14705882352941177),
#  ('pasar', 0.11764705882352941),
#  ('online', 0.11764705882352941),
#  ('beli', 0.10294117647058823),
#  ('toko', 0.08823529411764705),
#  ('jual', 0.07352941176470588),
#  ('ramai', 0.058823529411764705)]

# %%
# Gabungkan semua teks dari kolom 'stemmede_text' dalam DataFrame df_positif
all_text_s1 = ' '.join(word for word in df_positif['stemmed_text'].astype(str))

# Buat WordCloud dengan parameter yang telah disesuaikan
wordcloud = WordCloud(
    colormap='Set1',
    width=1000,
    height=1000,
    mode='RGBA',
    background_color='white',
    max_font_size=300,       # Set ukuran font maksimum yang lebih besar
    relative_scaling=0.5,    # Set scaling relatif untuk membuat kata-kata lebih rapat
    scale=3,                 # Set skala untuk meningkatkan resolusi
    # max_words=10             # Set limitasi kata
).generate(all_text_s1)

# Tampilkan WordCloud
plt.figure(figsize=(12, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('WordCloud Sentimen Positif')
plt.margins(x=0, y=0)
plt.show()

# %% [markdown]
# #### **Interpretasi Visualisasi Sentimen Positif:**
#
# - **Makna kata-kata pada Word Cloud:**
#   - Beberapa kata seperti `pasar`, `offline`, `biar` (biarin/biarkan), `toko`, dan `ramai` menunjukkan bahwa masyarakat melihat kebijakan ini sebagai peluang untuk memperkuat pasar tradisional dan toko offline, yang selama ini kalah bersaing dengan e-commerce akibat promo gratis ongkir masif dan menunjukkan dukungan agar toko fisik mendapat perhatian lebih, dengan harapan kebijakan ini menciptakan keseimbangan kompetisi antara penjual online dan offline.
#   - Beberapa kata seperti `bagus`, `setuju` menunjukkan bahwa masyarakat melihat kebijakan ini sebagai peluang untuk menghemat pengeluaran.
#
# - **Makna kata-kata pada Word Link:**
#   - Keterhubungan antara kata `biar`, `hemat`, dan `syukur` menunjukkan bahwa masyarakat merasa bersyukur karena kebijakan pengaturan diskon ongkir memungkinkan mereka berhemat. Hal ini terjadi karena sebelumnya, gratis ongkir sering mendorong belanja berlebihan, termasuk pembelian barang yang tidak benar-benar dibutuhkan, tanpa mempertimbangkan kebutuhan sebenarnya.
#   - Keterhubungan kata `biar`, `offline`, `toko`, `pasar`, dan `tradisional` menunjukkan bahwa masyarakat merasa senang karena pengaturan diskon ongkir melalui kebijakan Komdigi mendorong banyak orang untuk beralih ke pasar tradisional atau toko offline, yang dianggap mendapat keuntungan dari berkurangnya dominasi belanja online.
#   - Keterhubungan kata `biar`, `bagus`, `setuju`, `ekonomi`, dan `rata` menunjukkan bahwa masyarakat merasa senang karena pengaturan diskon ongkir melalui kebijakan Komdigi dianggap mendorong pertumbuhan ekonomi yang lebih merata, dengan memberikan peluang yang lebih adil bagi berbagai pelaku usaha, termasuk toko offline dan pasar tradisional.
#   - Keterhubungan kata `kurir` dan `sejahtera` menunjukkan bahwa masyarakat menganggap pengaturan diskon ongkir melalui kebijakan Komdigi dapat meningkatkan kesejahteraan kurir, dengan adanya upaya untuk memastikan pendapatan mereka tetap terjaga.

# %% [markdown]
# ### Sentimen Negatif

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
import networkx as nx
import matplotlib.pyplot as plt

# Ambil teks komentar dengan label i
# Pastikan df_negatif sudah terdefinisi sebelumnya, contoh:
# df_negatif = pd.DataFrame({'stemmed_text': ['contoh teks satu', 'teks contoh dua', 'kalimat ketiga contoh']})
texts = df_negatif['stemmed_text'].astype(str).str.lower().tolist()

# Gunakan CountVectorizer untuk bigram
vectorizer = CountVectorizer(ngram_range=(2, 2), min_df=2)
X = vectorizer.fit_transform(texts)
bigrams = vectorizer.get_feature_names_out()
counts = X.toarray().sum(axis=0)

# Gabungkan bigram dan frekuensinya
bigram_freq = list(zip(bigrams, counts))
bigram_freq_sorted = sorted(bigram_freq, key=lambda x: x[1], reverse=True)

# Ambil 50 bigram teratas (ubah jumlah sesuai kebutuhan)
top_n = 100
top_bigrams = [b[0] for b in bigram_freq_sorted[:top_n]]
edges = [tuple(b.split()) for b in top_bigrams]

# Buat graph dari bigram
G3 = nx.Graph()
G3.add_edges_from(edges)

# Hitung derajat setiap node
degrees = [G3.degree(node) for node in G3.nodes()]

# Tentukan faktor skala untuk ukuran node (sesuaikan sesuai kebutuhan)
scale_factor = 200

# Sesuaikan ukuran node berdasarkan derajatnya
node_sizes = [degree * scale_factor for degree in degrees]

# Visualisasi
plt.figure(figsize=(14, 10))
pos = nx.spring_layout(G3, k=0.6, seed=42) # k mengatur jarak antar node
nx.draw(
    G3, pos,
    with_labels=True,
    node_color='lightblue',
    edge_color='gray',
    node_size=node_sizes, # Gunakan ukuran node yang sudah disesuaikan
    font_size=10,
    font_weight='bold'
)
plt.title(f"Top {top_n} Word Link (Bigram Network) dari sentimen negatif (Ukuran Node Berdasarkan Derajat)", fontsize=16)
plt.show()

# %%
# Cek kata apa yang paling banyak punya edge (koneksi).
import networkx as nx

centrality = nx.degree_centrality(G3)
sorted(centrality.items(), key=lambda x: x[1], reverse=True)[:10]
# Out:
# [('kurir', 0.328125),
#  ('pemerintah', 0.21875),
#  ('urus', 0.171875),
#  ('beli', 0.125),
#  ('online', 0.125),
#  ('rakyat', 0.09375),
#  ('jual', 0.078125),
#  ('uang', 0.078125),
#  ('kerja', 0.0625),
#  ('senang', 0.0625)]

# %%
# Gabungkan semua teks dari kolom 'stemmede_text' dalam DataFrame df_negatif
all_text_s3 = ' '.join(word for word in df_negatif['stemmed_text'].astype(str))

# Buat WordCloud dengan parameter yang telah disesuaikan
wordcloud = WordCloud(
    colormap='Set1',
    width=1000,
    height=1000,
    mode='RGBA',
    background_color='white',
    max_font_size=300,       # Set ukuran font maksimum yang lebih besar
    relative_scaling=0.5,    # Set scaling relatif untuk membuat kata-kata lebih rapat
    scale=3,                 # Set skala untuk meningkatkan resolusi
    # max_words=10             # Set limitasi kata
).generate(all_text_s3)

# Tampilkan WordCloud
plt.figure(figsize=(12, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('WordCloud Sentimen Negatif')
plt.margins(x=0, y=0)
plt.show()

# %% [markdown]
# #### **Interpretasi Visualisasi Sentimen Negatif:**
#
# - **Makna kata-kata pada Word Cloud:**
#   - Kata-kata seperti `susah`, `mahal`, `beli`, `online`, `sepi` dan `rakyat` menunjukkan bahwa masyarakat merasa terbebani dan khawatir kebijakan ini membuat belanja online menjadi lebih mahal dan sulit, sehingga memengaruhi daya beli masyarakat umum.
#   - Kata `pemerintah`, `atur`, `korupsi`, dan `konoha` mengindikasikan bahwa masyarakat tidakpuas terhadap pemerint karena kebijakan ini kurang tepat atau bahkan dianggap merugikan dan juga dibandingkan mengurusi hal seperti gratis ongkir lebih baik mengurusi masalah seperti korupsi.
#   - Kata `kurir`, `gaji`, `kasih`, dan `kerja` mencerminkan kekhawatiran bahwa kebijakan ini dapat memperburuk pendapatan dan kondisi kerja kurir.
#
# - **Makna kata-kata pada Word Link:**
#
#   - Keterhubungan kata `kurir`,`susah`, `gaji`, dan `kasih` menunjukkan bahwa masyarakat khawatir kebijakan pengaturan diskon ongkir dapat menurunkan pendapatan kurir, sehingga membuat mereka sulit memenuhi kebutuhan sehari-hari.
#   - Keterhubungan kata `beli`, `online`, dan `mahal` mengindikasikan bahwa masyarakat merasa belanja online menjadi lebih mahal akibat kebijakan ini, sehingga memengaruhi kebiasaan belanja mereka.
#   - Keterhubungan kata `pemerintah`, `atur`, dan `ngurus` menunjukkan bahwa masyarakat kesal dengan aksi pemerintah membuat kebijakan pembatasan gratis ongkir yang mana hal seperti ini sepele, masyarakat lebih berharap bahwa pemerintah seharusnya lebih fokus menangani masalah lain yang lebih penting dan urgent.
#   - Keterhubungan kata `Kalimantan`, dan `mahal` mengindikasikan bahwa masyarakat di daerah terpencil merasa biaya pengiriman menjadi lebih mahal, memperparah kesenjangan akses belanja online.

# %% [markdown]
# ### Sentimen Netral

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
import networkx as nx
import matplotlib.pyplot as plt

# Ambil teks komentar dengan label i
# Pastikan df_netral sudah terdefinisi sebelumnya, contoh:
# df_netral = pd.DataFrame({'stemmed_text': ['contoh teks satu', 'teks contoh dua', 'kalimat ketiga contoh']})
texts = df_netral['stemmed_text'].astype(str).str.lower().tolist()

# Gunakan CountVectorizer untuk bigram
vectorizer = CountVectorizer(ngram_range=(2, 2), min_df=2)
X = vectorizer.fit_transform(texts)
bigrams = vectorizer.get_feature_names_out()
counts = X.toarray().sum(axis=0)

# Gabungkan bigram dan frekuensinya
bigram_freq = list(zip(bigrams, counts))
bigram_freq_sorted = sorted(bigram_freq, key=lambda x: x[1], reverse=True)

# Ambil 50 bigram teratas (ubah jumlah sesuai kebutuhan)
top_n = 100
top_bigrams = [b[0] for b in bigram_freq_sorted[:top_n]]
edges = [tuple(b.split()) for b in top_bigrams]

# Buat graph dari bigram
G2 = nx.Graph()
G2.add_edges_from(edges)

# Hitung derajat setiap node
degrees = [G2.degree(node) for node in G2.nodes()]

# Tentukan faktor skala untuk ukuran node (sesuaikan sesuai kebutuhan)
scale_factor = 200

# Sesuaikan ukuran node berdasarkan derajatnya
node_sizes = [degree * scale_factor for degree in degrees]

# Visualisasi
plt.figure(figsize=(14, 10))
pos = nx.spring_layout(G2, k=0.6, seed=42) # k mengatur jarak antar node
nx.draw(
    G2, pos,
    with_labels=True,
    node_color='lightblue',
    edge_color='gray',
    node_size=node_sizes, # Gunakan ukuran node yang sudah disesuaikan
    font_size=10,
    font_weight='bold'
)
plt.title(f"Top {top_n} Word Link (Bigram Network) dari sentimen netral (Ukuran Node Berdasarkan Derajat)", fontsize=16)
plt.show()

# %%
# Cek kata apa yang paling banyak punya edge (koneksi).
import networkx as nx

centrality = nx.degree_centrality(G2)
sorted(centrality.items(), key=lambda x: x[1], reverse=True)[:10]
# Out:
# [('kurir', 0.42424242424242425),
#  ('bayar', 0.21212121212121213),
#  ('suka', 0.13636363636363635),
#  ('uang', 0.12121212121212122),
#  ('affiliate', 0.10606060606060606),
#  ('kasih', 0.10606060606060606),
#  ('paket', 0.10606060606060606),
#  ('lebihin', 0.09090909090909091),
#  ('lebih', 0.07575757575757576),
#  ('harga', 0.07575757575757576)]

# %%
# Gabungkan semua teks dari kolom 'stemmede_text' dalam DataFrame df_netral
all_text_s2 = ' '.join(word for word in df_netral['stemmed_text'].astype(str))

# Buat WordCloud dengan parameter yang telah disesuaikan
wordcloud = WordCloud(
    colormap='Set1',
    width=1000,
    height=1000,
    mode='RGBA',
    background_color='white',
    max_font_size=300,       # Set ukuran font maksimum yang lebih besar
    relative_scaling=0.5,    # Set scaling relatif untuk membuat kata-kata lebih rapat
    scale=3,                 # Set skala untuk meningkatkan resolusi
    # max_words=10             # Set limitasi kata
).generate(all_text_s2)

# Tampilkan WordCloud
plt.figure(figsize=(12, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('WordCloud Sentimen Netral')
plt.margins(x=0, y=0)
plt.show()

# %% [markdown]
# #### **Interpretasi Visualisasi Sentimen Netral:**
#
# - **Makna kata-kata pada Word Cloud:**
#   - Kata-kata seperti `kurir`, `bayar`, `kasih`, dan `suka` menunjukkan bahwa masyarakat membahas interaksi dengan kurir secara netral, termasuk praktik memberikan lebih sebagai tanda terima kasih atau sedekah, tanpa emosi yang kuat.
#   - Kata `online`, `shopee`, dan `beli` mengindikasikan bahwa beberapa masyarakat merasa tidak masalah dan tetap melakukan cek out.
#   - Kata `asmara`, `gen`, `trailer`, dan `affiliate` mencerminkan adanya topik tidak relevan, seperti diskusi tentang acara tv karena salah satu sumber data ini merupakan akun tiktok stasiun tv yang akan menayangkan series sinetron atau promosi TikTok, yang tidak berkaitan langsung dengan kebijakan Komdigi.
#
# - **Makna kata-kata pada Word Link:**
#
#   - Keterhubungan antara kata `kurir`, `paket`, `suka`, `lebih`, `lebihin`, `kasih`, dan `bayar` menunjukkan bahwa masyarakat membahas secara netral tentang proses pengiriman dan pembayaran jasa kurir, termasuk praktik memberikan lebih sebagai tanda terima kasih atau sedekah, tanpa menunjukkan emosi kuat.
#   - Keterhubungan kata `affiliate`, `tiktok`, dan `bantu` mencerminkan adanya topik tidak relevan, seperti promosi afiliasi TikTok, yang tidak terkait langsung dengan kebijakan Komdigi.
#   - Hubungan antara kata `trailer`, `asmara`, dan `gen` mengindikasikan adanya topik yang tidak relevan, seperti pembahasan acara televisi, karena salah satu sumber data berasal dari akun TikTok stasiun TV yang akan menayangkan sinetron yang tidak berhubungan dengan kebijakan Komdigi.

# %% [markdown]
# ## Tren Percakapan Publik di Media Sosial

# %%
dfm = df.copy()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import timedelta

# Pastikan kolom waktu bertipe datetime
dfm['createTimeISO'] = pd.to_datetime(dfm['createTimeISO'])

# Hitung jumlah percakapan per hari
daily_counts = dfm.groupby(dfm['createTimeISO'].dt.date).size()

# Tentukan tanggal puncak
peak_date = pd.to_datetime('2025-05-20').date()

# Ambil periode +/- 5 hari dari tanggal puncak
start_date = peak_date - timedelta(days=5)
end_date = peak_date + timedelta(days=5)

window_counts = daily_counts.loc[start_date:end_date]

# Plot
plt.figure(figsize=(10, 5))
plt.plot(window_counts.index, window_counts.values, marker='o', linestyle='-', color='darkblue')
plt.axvline(peak_date, color='red', linestyle='--', label='Peak Day')
plt.title('Tren Percakapan')
plt.xlabel('Tanggal')
plt.ylabel('Jumlah Percakapan')
plt.grid(True)
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# Rasio decay 1-2 hari setelah puncak (opsional, insight numerik)
day1 = peak_date + timedelta(days=1)
day2 = peak_date + timedelta(days=2)
decay_1 = daily_counts.get(day1, 0) / daily_counts.get(peak_date, 1)
decay_2 = daily_counts.get(day2, 0) / daily_counts.get(peak_date, 1)

print(f"Penurunan hari +1: {decay_1:.2%}")
print(f"Penurunan hari +2: {decay_2:.2%}")
# Out:
# Penurunan hari +1: 32.93%
# Penurunan hari +2: 5.37%

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Pastikan kolom waktu bertipe datetime
dfm['createTimeISO'] = pd.to_datetime(dfm['createTimeISO'])

# Ekstrak tanggal (tanpa jam)
dfm['date'] = dfm['createTimeISO'].dt.date

# Peta label ke nama sentimen
sentiment_map = {1: 'Positif', 2: 'Netral', 3: 'Negatif'}
dfm['sentiment'] = dfm['label'].map(sentiment_map)

# Hitung jumlah komentar per hari per sentimen
sentiment_trend = dfm.groupby(['date', 'sentiment']).size().unstack(fill_value=0)

# Visualisasi tren harian berdasarkan sentimen
plt.figure(figsize=(14, 6))

# Plot garis per sentimen
for sentiment_category in sentiment_trend.columns:
    sns.lineplot(data=sentiment_trend, x=sentiment_trend.index, y=sentiment_category, marker='o', label=sentiment_category)

# Atur tampilan grafik
plt.title('Tren Jumlah Komentar Harian Berdasarkan Sentimen')
plt.xlabel('Tanggal')
plt.ylabel('Jumlah Komentar')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.legend(title='Sentimen')
plt.show()

# %% [markdown]
# * **Lonjakan Sentimen Negatif pada Puncak**: Sentimen negatif mendominasi dengan puncak 1750 komentar pada 21 Mei 2025, menunjukkan penolakan publik yang kuat terhadap kebijakan ini. Lonjakan ini kemungkinan dipicu oleh pengumuman atau persepsi awal yang negatif, memerlukan perhatian khusus untuk klarifikasi.
# * **Keterlibatan Sentimen Netral**: Sentimen netral mencapai 1000 komentar pada puncak, mencerminkan diskusi publik yang belum memihak atau masih mencari pemahaman. Tingkat keterlibatan ini menunjukkan adanya kelompok yang terbuka untuk dialog atau menunggu informasi lebih lanjut.
# * **Minimnya Sentimen Positif**: Sentimen positif hanya mencapai 250 komentar, mengindikasikan dukungan terbatas terhadap peraturan ini. Rendahnya dukungan positif menyoroti tantangan dalam membangun narasi yang menguntungkan bagi kebijakan ini di mata publik.
# * **Penurunan Minat Publik**: Semua sentimen menurun drastis dan stabil di bawah 100 komentar hingga 1 Juni 2025, menandakan minat publik yang cepat mereda setelah puncak. Hal ini mengisyaratkan bahwa isu ini bersifat sementara, tetapi memerlukan pendekatan strategis untuk menjaga perhatian.
# * **Sentimen Negatif Tetap Relevan**: Meski perbincangan mereda, sentimen negatif tetap sedikit lebih dominan dibandingkan lainnya, menunjukkan bahwa ketidakpuasan dasar masih ada di kalangan tertentu. Menunjukkan perlunya tindakan lanjutan untuk mengatasi akar masalah.

# %% [markdown]
# ## Sentimen berdasarkan waktu

# %%
dft = df.copy()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Pastikan kolom waktu sudah dalam datetime
dft['createTimeISO'] = pd.to_datetime(dft['createTimeISO'])

# Copy the 'label' column from df_text to dft
dft['label'] = df_text['label']

# Set as index
dft = dft.set_index('createTimeISO')

# Hitung jumlah komentar per hari per label
sentiment_shift = dft.groupby([dft.index.date, 'label']).size().unstack(fill_value=0)

# Normalisasi agar jadi proporsi per hari
sentiment_shift = sentiment_shift.div(sentiment_shift.sum(axis=1), axis=0)

# Konversi kembali index ke datetime untuk plot
sentiment_shift.index = pd.to_datetime(sentiment_shift.index)

# Plot
plt.figure(figsize=(12, 6))
sentiment_shift.plot(kind='line', marker='o')
plt.title('Sentiment Shift Over Time (Daily)')
plt.xlabel('Date')
plt.ylabel('Proportion')
plt.grid(True)
plt.legend(title='Sentiment')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-51-158b9ace540c>:15: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   sentiment_shift = dft.groupby([dft.index.date, 'label']).size().unstack(fill_value=0)

# %% [markdown]
# 1. Sentimen Positif (Label 1 - Biru) Rendan dan stabil
#   * Selalu di bawah 10%, cenderung stabil tanpa lonjakan.
#   * Ini menunjukkan bahwa komentar bersifat positif sangat sedikit dan tidak mengalami peningkatan signifikan selama rentang waktu ini.
#
# 2. Sentimen Netral (Label 2 - Oranye) Fluktuatif
#   * Berkisar antara 25–55%, mengalami fluktuasi yang lebih besar dibanding sentimen lain.
#   * Beberapa hari seperti 19 dan 24 Mei, proporsinya melonjak, mengindikasikan topik netral (mungkin informatif atau deskriptif) menjadi lebih banyak dibicarakan.
#
# 3. Sentimen Negatif (Label 3 - Hijau) Dominan
#   * Secara konsisten mendominasi sepanjang periode, dengan proporsi sekitar 50–70% hampir setiap hari.
#   * Menunjukkan bahwa mayoritas komentar di video yang dianalisis cenderung bersifat negatif selama periode tersebut.
# Selalu di bawah 10%, cenderung stabil tanpa lonjakan.

# %% [markdown]
# ## topic modelling

# %% [markdown]
# ### positif

# %%
# !pip install bertopic
# Out:
# Collecting bertopic
#   Downloading bertopic-0.17.0-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: hdbscan>=0.8.29 in /usr/local/lib/python3.11/dist-packages (from bertopic) (0.8.40)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.11/dist-packages (from bertopic) (2.0.2)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.11/dist-packages (from bertopic) (2.2.2)
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.11/dist-packages (from bertopic) (5.24.1)
# Requirement already satisfied: scikit-learn>=1.0 in /usr/local/lib/python3.11/dist-packages (from bertopic) (1.6.1)
# Requirement already satisfied: sentence-transformers>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from bertopic) (4.1.0)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.11/dist-packages (from bertopic) (4.67.1)
# Requirement already satisfied: umap-learn>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from bertopic) (0.5.7)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.11/dist-packages (from hdbscan>=0.8.29->bertopic) (1.15.3)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.11/dist-packages (from hdbscan>=0.8.29->bertopic) (1.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.5->bertopic) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.5->bertopic) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.5->bertopic) (2025.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly>=4.7.0->bertopic) (9.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly>=4.7.0->bertopic) (24.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.0->bertopic) (3.6.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=0.4.1->bertopic) (4.52.3)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=0.4.1->bertopic) (2.6.0+cu124)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.32.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=0.4.1->bertopic) (11.2.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=0.4.1->bertopic) (4.13.2)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.11/dist-packages (from umap-learn>=0.5.0->bertopic) (0.60.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.11/dist-packages (from umap-learn>=0.5.0->bertopic) (0.5.13)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2025.3.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2.32.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (1.1.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.2->umap-learn>=0.5.0->bertopic) (0.43.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.1.5->bertopic) (1.17.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (0.5.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2025.4.26)
# Downloading bertopic-0.17.0-py3-none-any.whl (150 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.6/150.6 kB 8.8 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 71.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 37.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 51.6 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.0 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 16.5 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 43.7 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, bertopic
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed bertopic-0.17.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
from bertopic import BERTopic

# %%
from bertopic import BERTopic
from umap import UMAP
from hdbscan import HDBSCAN

# %%
text_pos = df_text[df_text['label'] == 1]

# %%
texts1 = text_pos['stemmed_text']
texts1
# Out:
# 54      beban kurir gimanasi buka syukur kurir dapet i...
# 61      beban kuriraku kurir senang bawa banyakbanyak ...
# 62           papa hapus biar jual online sepi kurir kerja
# 106                    suami kurir berat paket paket gaji
# 133              beban woy gaji kurir gantung paket kirim
#                               ...
# 5474                                                hebat
# 5479                             syukur kabar umkn daerah
# 5481                                  senang dukung kurir
# 5485                                     mantap kewa jual
# 5493                                                keren
# Name: stemmed_text, Length: 354, dtype: object

# %%
texts1 = texts1.astype(str).tolist()

# %%
# Inisialisasi model UMAP dengan random_state
umap_model = UMAP(n_neighbors=15,
                  n_components=5,
                  min_dist=0.0,
                  metric='cosine',
                  random_state=37)

# Inisialisasi model clustering HDBSCAN dengan random_state
hdbscan_model = HDBSCAN(min_cluster_size=10,
                        metric='euclidean',
                        cluster_selection_method='eom',
                        prediction_data=True)

# Inisialisasi BERTopic dengan model yang sudah disetel random_state
topic_model1 = BERTopic(
    language="indonesian",
    calculate_probabilities=True,
    umap_model=umap_model,
    hdbscan_model=hdbscan_model,
    verbose=True
)

# Fit model
topics, probs = topic_model1.fit_transform(texts1)

# Tampilkan topik dominan
topic_model1.get_topic_info()
# Out:
# 2025-06-05 06:57:03,708 - BERTopic - Embedding - Transforming documents to embeddings.
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.89k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/645 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/471M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/12 [00:00<?, ?it/s]
# 2025-06-05 06:57:30,409 - BERTopic - Embedding - Completed ✓
# 2025-06-05 06:57:30,411 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-06-05 06:57:39,135 - BERTopic - Dimensionality - Completed ✓
# 2025-06-05 06:57:39,136 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2025-06-05 06:57:39,159 - BERTopic - Cluster - Completed ✓
# 2025-06-05 06:57:39,162 - BERTopic - Representation - Fine-tuning topics using representation models.
# 2025-06-05 06:57:39,181 - BERTopic - Representation - Completed ✓
#    Topic  Count                                  Name  \
# 0     -1     11  -1_pemerintah_nyalahin_saudara_salah
# 1      0    122               0_hemat_bagus_biar_baca
# 2      1    100            1_offline_online_jual_biar
# 3      2     60               2_kurir_paket_gaji_bawa
# 4      3     50               3_pasar_biar_jual_ramai
# 5      4     11             4_toko_bagus_kadang_jalan
#
#                                       Representation  \
# 0  [pemerintah, nyalahin, saudara, salah, perang,...
# 1  [hemat, bagus, biar, baca, syukur, setuju, bul...
# 2  [offline, online, jual, biar, dagang, beli, to...
# 3  [kurir, paket, gaji, bawa, kasi, sejahtera, ba...
# 4  [pasar, biar, jual, ramai, setuju, tradisional...
# 5  [toko, bagus, kadang, jalan, biar, mager, halm...
#
#                                  Representative_Docs
# 0  [kasih untung nyalahin pemerintah, dengerin se...
# 1        [bagus biar, bagus hemat, bagus biar hemat]
# 2      [bagus dagang offline toko, offline, offline]
# 3  [untung kurir nganter paket bawa, suami kurir ...
# 4  [biar pasar ramai, biar pasar ramai, setuju bi...
# 5  [bagus biar tdk mager jalan mall pasar toko, b...

# %%
X =  topic_model1.get_topic_info()
X.head(10)
# Out:
#    Topic  Count                                  Name  \
# 0     -1     11  -1_pemerintah_nyalahin_saudara_salah
# 1      0    122               0_hemat_bagus_biar_baca
# 2      1    100            1_offline_online_jual_biar
# 3      2     60               2_kurir_paket_gaji_bawa
# 4      3     50               3_pasar_biar_jual_ramai
# 5      4     11             4_toko_bagus_kadang_jalan
#
#                                       Representation  \
# 0  [pemerintah, nyalahin, saudara, salah, perang,...
# 1  [hemat, bagus, biar, baca, syukur, setuju, bul...
# 2  [offline, online, jual, biar, dagang, beli, to...
# 3  [kurir, paket, gaji, bawa, kasi, sejahtera, ba...
# 4  [pasar, biar, jual, ramai, setuju, tradisional...
# 5  [toko, bagus, kadang, jalan, biar, mager, halm...
#
#                                  Representative_Docs
# 0  [kasih untung nyalahin pemerintah, dengerin se...
# 1        [bagus biar, bagus hemat, bagus biar hemat]
# 2      [bagus dagang offline toko, offline, offline]
# 3  [untung kurir nganter paket bawa, suami kurir ...
# 4  [biar pasar ramai, biar pasar ramai, setuju bi...
# 5  [bagus biar tdk mager jalan mall pasar toko, b...

# %%
topic_model1.visualize_topics().show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="50e1d14c-064e-49d6-b1c3-0d4500ad5f58" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("50e1d14c-064e-49d6-b1c3-0d4500ad5f58")) {                    Plotly.newPlot(                        "50e1d14c-064e-49d6-b1c3-0d4500ad5f58",                        [{"customdata":[[0,"hemat | bagus | biar | baca | syukur",122],[1,"offline | online | jual | biar | dagang",100],[2,"kurir | paket | gaji | bawa | kasi",60],[3,"pasar | biar | jual | ramai | setuju",50],[4,"toko | bagus | kadang | jalan | biar",11]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[122,100,60,50,11],"sizemode":"area","sizeref":0.07625,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[-3.9854681,-5.3774986,-4.648575,-4.807672,-5.6609135],"xaxis":"x","y":[7.5106893,8.51846,6.689368,7.46445,7.9507365],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale ...

# %%
topic_model1.visualize_barchart(top_n_topics=5)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b569e624-9e08-432e-93d3-d539f4c2a5e7" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b569e624-9e08-432e-93d3-d539f4c2a5e7")) {                    Plotly.newPlot(                        "b569e624-9e08-432e-93d3-d539f4c2a5e7",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.06080456835914553,0.06548362818817294,0.07384957817913365,0.07968538896034384,0.0797243751540343],"y":["syukur  ","baca  ","biar  ","bagus  ","hemat  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.06818797557784483,0.07143890026043027,0.0776688848762006,0.14753164032248975,0.16621963477885413],"y":["dagang  ","biar  ","jual  ","online  ","offline  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.06176862636015384,0.07215087537353154,0.10915253780367755,0.13328919792955343,0.2456809827560136],"y":["kasi  ","bawa  ","gaji  ","paket  ","kurir  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.0761706667500038,0.09220180431307849,0.10156059973093756,0.1084810185471112,0.1608496725271978],"y":["setuju  ","ramai  ","jual  ","biar  ","pasar  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.1297599875698138,0.12984152206453328,0.15583788260781942,0.15648623895379743,0.48261524276507156],"y":["biar  ","jalan  ","kadang  ","bagus  ","toko  "],"type":"bar","xaxis":"x5","yaxis":"y5"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.666666666 ...

# %% [markdown]
# * **Penghematan Jadi Prioritas**: Sebagian publik melihat pembatasan ongkir sebagai peluang untuk lebih hemat, dengan sikap positif terhadap pengelolaan biaya. Menunjukkan adanya apresiasi terhadap kebijakan yang mendorong pengendalian pengeluaran, terutama di kalangan konsumen yang sadar biaya.
# * **Perbandingan Online dan Offline**: Diskusi tentang pilihan belanja online vs. offline mencerminkan fleksibilitas masyarakat dalam menyesuaikan strategi belanja, dengan fokus pada aktivitas jual-beli yang hemat. Menunjukkan ada adopsi yang adaptif terhadap perubahan kebijakan.
# * **Kekhawatiran terhadap Kurir**: Empati terhadap kurir muncul karena khawatir pendapatan mereka terdampak akibat penurunan belanja online, menunjukkan perhatian sosial yang tetap ada meski sentimen positif dominan. Ini bisa menjadi dasar untuk mendukung pekerja logistik.

# %% [markdown]
# ### netral

# %%
text_net = df_text[df_text['label'] == 2]

# %%
texts2 = text_net['stemmed_text']
texts2
# Out:
# 1            trailer asmara gen
# 2                         kaget
# 3            trailer asmara gen
# 4            trailer asmara gen
# 5       trailer asmara gen miin
#                  ...
# 5475                     keduaa
# 5478             folow bre like
# 5488                 bantu mula
# 5492                     berita
# 5494       back affiliate cepat
# Name: stemmed_text, Length: 2092, dtype: object

# %%
texts2 = texts2.astype(str).tolist()

# %%
# Inisialisasi model UMAP dengan random_state
umap_model = UMAP(n_neighbors=15,
                  n_components=5,
                  min_dist=0.0,
                  metric='cosine',
                  random_state=37)

# Inisialisasi model clustering HDBSCAN dengan random_state
hdbscan_model = HDBSCAN(min_cluster_size=10,
                        metric='euclidean',
                        cluster_selection_method='eom',
                        prediction_data=True)

# Inisialisasi BERTopic dengan model yang sudah disetel random_state
topic_model2 = BERTopic(
    language="indonesian",
    calculate_probabilities=True,
    umap_model=umap_model,
    hdbscan_model=hdbscan_model,
    verbose=True
)

# Fit model
topics, probs = topic_model2.fit_transform(texts2)

# Tampilkan topik dominan
topic_model2.get_topic_info()
# Out:
# 2025-06-05 06:57:40,598 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/66 [00:00<?, ?it/s]
# 2025-06-05 06:57:44,818 - BERTopic - Embedding - Completed ✓
# 2025-06-05 06:57:44,819 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-06-05 06:57:53,731 - BERTopic - Dimensionality - Completed ✓
# 2025-06-05 06:57:53,732 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2025-06-05 06:57:54,007 - BERTopic - Cluster - Completed ✓
# 2025-06-05 06:57:54,011 - BERTopic - Representation - Fine-tuning topics using representation models.
# 2025-06-05 06:57:54,063 - BERTopic - Representation - Completed ✓
#     Topic  Count                                            Name  \
# 0      -1    693                       -1_kurir_paket_suka_kasih
# 1       0    174                        0_bayar_uang_mahal_harga
# 2       1    106                                           1____
# 3       2     86                        2_kurir_bayar_gaji_paket
# 4       3     67                      3_trailer_gen_asmara_manaa
# 5       4     52                          4_vip_jual_shopee_toko
# 6       5     49              5_semangat_sekolah_nanggung_sukses
# 7       6     42                            6_eh_haha_hihi_halah
# 8       7     42                  7_kurir_langgan_gantung_nambah
# 9       8     42                       8_mslh_sedih_serius_kesal
# 10      9     39  9_astaghfirullah_mao_nasywahhafizindonesia_sue
# 11     10     38                  10_back_affiliate_tiktok_backk
# 12     11     36                              11_serah_pp_gt_tim
# 13     12     35                        12_online_hobi_donk_biar
# 14     13     34                             13_akhu_ynk_ak_ribu
# 15     14     34                14_pemerintah_rakyat_urus_senang
# 16     15     32                     15_sedekah_anggap_minum_teh
# 17     16     30                   16_bulatin_dikit_bulat_kuring
# 18     17     29                17_gen_asmara_trailer_dehpenting
# 19     18     29                18_affiliate_mula_bantu_semangat
# 20     19     26                          19_kakak_libur_iy_dksh
# 21     20     25                20_buletin_kentut_digidaw_dhonie
# 22     21     24                    21_kasih_syukur_tips_kembali
# 23     22     24                           22_akun_hp_otw_tenang
# 24     23     22                      23_paket_sen_mrk_digenapin
# 25     24     20                        24_klau_folow_bre_dowlod
# 26     25     20                    25_kurir_nemu_nganggur_sekrg
# 27     26     20               26_lebihin_lebih_ngelempengin_ane
# 28     27     19                       27_back_semuaa_wa_kembali
# 29     28     18                     28_kadang_ska_war_akukadang
# 30     29     18              29_kerja_bobot_pemerintaaaahh_boss
# 31     30     17                      30_online_beli_laku_barang
# 32     31     16                        31_paham_ok_setuju_gituh
# 33     32     16                              32_iy_me_like_aiih
# 34     33     16       33_kalimantan_pendeta_marcel_presenternya
# 35     34     14                 34_kasih_akubmalah_kisah_itungn
# 36     35     14                   35_indonesia_korupsi_pos_urus
# 37     36     14                     36_samaa_indrii_mila_rasain
# 38     37     13                     37_gin_panas_harusya_hangus
# 39     38     13                           38_gas_bensin_mn_tera
# 40     39     13               39_tertawa_lucu_apakabar_kaarenna
# 41     40     11                       40_suka_sen_kurir_lebihin
# 42     41     10                          41_masak_kelas_cook_jm
#
#                                        Representation  \
# 0   [kurir, paket, suka, kasih, jujur, biar, lebih...
# 1   [bayar, uang, mahal, harga, biaya, beli, baran...
# 2                                [, , , , , , , , , ]
# 3   [kurir, bayar, gaji, paket, lebihin, pas, uang...
# 4   [trailer, gen, asmara, manaa, bolak, agzz, tak...
# 5   [vip, jual, shopee, toko, ad, beli, pasar, mar...
# 6   [semangat, sekolah, nanggung, sukses, segitu, ...
# 7   [eh, haha, hihi, halah, aduh, yahhhh, yeu, ela...
# 8   [kurir, langgan, gantung, nambah, minta, tip, ...
# 9   [mslh, sedih, serius, kesal, bangett, daerah, ...
# 10  [astaghfirullah, mao, nasywahhafizindonesia, s...
# 11  [back, affiliate, tiktok, backk, tiktokamanah,...
# 12  [serah, pp, gt, tim, ko, et, anti, kam, indy, ...
# 13  [online, hobi, donk, biar, untung, org, bulan,...
# 14  [akhu, ynk, ak, ribu, bayar, pas, dya, commerc...
# 15  [pemerintah, rakyat, urus, senang, swasta, kon...
# 16  [sedekah, anggap, minum, teh, dilebihin, kopi,...
# 17  [bulatin, dikit, bulat, kuring, keranjang, kda...
# 18  [gen, asmara, trailer, dehpenting, alih, gaped...
# 19  [affiliate, mula, bantu, semangat, tembus, sup...
# 20  [kakak, libur, iy, dksh, boro, anjay, dlebihin...
# 21  [buletin, kentut, digidaw, dhonie, cova, hesti...
# 22  [kasih, syukur, tips, kembali, tegun, tuhbiar,...
# 23  [akun, hp, otw, tenang, bulan, byk, gara, bany...
# 24  [paket, sen, mrk, digenapin, rbu, segitu, tota...
# 25  [klau, folow, bre, dowlod, dimna, gaskeun, muk...
# 26  [kurir, nemu, nganggur, sekrg, ajaapa, bgini, ...
# 27  [lebihin, lebih, ngelempengin, ane, kes, sya, ...
# 28  [back, semuaa, wa, kembali, blanjaan, aku, aff...
# 29  [kadang, ska, war, akukadang, ahir, kembar, ks...
# 30  [kerja, bobot, pemerintaaaahh, boss, ngangur, ...
# 31  [online, beli, laku, barang, pasar, sepi, harg...
# 32  [paham, ok, setuju, gituh, begituu, selamat, h...
# 33  [iy, me, like, aiih, iyee, iyaaa, weyyy, iitaa...
# 34  [kalimantan, pendeta, marcel, presenternya, ga...
# 35  [kasih, akubmalah, kisah, itungn, bintang, hal...
# 36  [indonesia, korupsi, pos, urus, konoha, flimdr...
# 37  [samaa, indrii, mila, rasain, sariii, kangen, ...
# 38  [gin, panas, harusya, hangus, gebrak, bln, vou...
# 39  [gas, bensin, mn, tera, ngasik, mintak, keluar...
# 40  [tertawa, lucu, apakabar, kaarenna, ngebuletin...
# 41  [suka, sen, kurir, lebihin, daerah, enak, begt...
# 42  [masak, kelas, cook, jm, kakberapa, jarak, kek...
#
#                                   Representative_Docs
# 0   [tu org lebihin kembali kurir perak semenjak s...
# 1                         [bayar, bayar bayar, bayar]
# 2                                              [, , ]
# 3   [kurir langgan bayar lebih, kurir bilang bayar...
# 4   [trailer asmara gen manaa, cari trailer asmara...
# 5               [toko shopee, shopee vip, vip shopee]
# 6   [semangat sukses, semangat mula, bang bahas ga...
# 7                   [eh nambah paket aduh, eh, eh eh]
# 8   [kurir langgan tugas daerah situ klu kurir tmp...
# 9   [daerah yag tdk nikmat ntt apalg pulau sumba, ...
# 10  [bantu naikin followes gmna stag, sue sue do n...
# 11  [back tiktok affiliate, back affiliate tiktok,...
# 12                        [serah, serah, gc pp pasar]
# 13       [biar online, online lebihin, online online]
# 14  [baca komen bayar nang korit bel beli bayar sl...
# 15  [pemerintah urus senang rakyat susah, pemerint...
# 16  [suka lebih kasih anggap sedekah, suka lebihin...
# 17  [lebih bulatin atasanya bawa bulatin bawah, mn...
# 18  [trailer asmara gen, trailer asmara gen, trail...
# 19  [bantu affiliate mula kakak, bantu affiliate m...
# 20                              [kakak, kakak, kakak]
# 21                        [buletin, buletin, buletin]
# 22  [kasih lebih, kasih lebihin, kasih kasih lebihin]
# 23  [akun bulan, akun sp akun laz akun ttk akun to...
# 24  [kurir tmpt paket digenapin total paket digena...
# 25  [lohh langgan lebih perak bayang, folow bre li...
# 26  [lihat ajaapa freongkirklo otomatis kurir ngan...
# 27                        [lebihin, lebihin, lebihin]
# 28                                 [back, back, back]
# 29  [kadang suka, kadang kadang kadang buletin, ka...
# 30       [pemerintah kerja, kurir kerja, kurir kerja]
# 31  [beli online ben laku, jujur blm beli barang o...
# 32                [paham, gituh loeudh hin, ok paham]
# 33                                       [iy, iy, iy]
# 34  [salah fokus presenternya pendeta marcel gasii...
# 35                              [kasih, kasih, kasih]
# 36  [pemerintah kehabisa kerja kyk gin urus ohh in...
# 37                    [samaa, heleh enek, kangen exo]
# 38  [harusya gin, bahasa sederhana gin aktif vouch...
# 39  [gas jual, ndk bund kasi mas kurir nganterin c...
# 40                        [tertawa, tertawa, tertawa]
# 41  [suka lebihin sma kurir nyabiasa kurir langgan...
# 42  [masak tulungagung jarak jm rumah ak, nemuin k...

# %%
topic2 = topic_model2.get_topic_info()
topic2.iloc[2]
# Out:
# Topic                                     1
# Count                                   106
# Name                                  1____
# Representation         [, , , , , , , , , ]
# Representative_Docs                  [, , ]
# Name: 2, dtype: object

# %%
topic_model2.visualize_topics().show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4f1ebca9-fdd5-4805-bad2-5a61c85e95da" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4f1ebca9-fdd5-4805-bad2-5a61c85e95da")) {                    Plotly.newPlot(                        "4f1ebca9-fdd5-4805-bad2-5a61c85e95da",                        [{"customdata":[[0,"bayar | uang | mahal | harga | biaya",174],[1," |  |  |  | ",106],[2,"kurir | bayar | gaji | paket | lebihin",86],[3,"trailer | gen | asmara | manaa | bolak",67],[4,"vip | jual | shopee | toko | ad",52],[5,"semangat | sekolah | nanggung | sukses | segitu",49],[6,"eh | haha | hihi | halah | aduh",42],[7,"kurir | langgan | gantung | nambah | minta",42],[8,"mslh | sedih | serius | kesal | bangett",42],[9,"astaghfirullah | mao | nasywahhafizindonesia | sue | manusia",39],[10,"back | affiliate | tiktok | backk | tiktokamanah",38],[11,"serah | pp | gt | tim | ko",36],[12,"online | hobi | donk | biar | untung",35],[13,"akhu | ynk | ak | ribu | bayar",34],[14,"pemerintah | rakyat | urus | senang | swasta",34],[15,"sedekah | anggap | minum | teh | dilebihin",32],[16,"bulatin | dikit | bulat | kuring | keranjang",30],[17,"gen | asmara | trailer | dehpenting | alih",29],[18,"affiliate | mula | bantu | semangat | tembus",29],[19,"kakak | libur | iy | dksh | boro",26],[20,"buletin | kentut | digidaw | dhonie | cova",25],[21,"kasih | syukur | tips | kembali | tegun",24],[22,"akun | hp | otw | tenang | bulan",24],[23,"paket | sen | mrk | digenapin | rbu",22],[24,"klau | folow | bre | dowlod | dimna",20],[25,"kurir | nemu | nganggur | sekrg | ajaapa",20],[26,"lebihin | lebih | ngelempengin | ane | kes",20],[27,"back | semuaa | wa | kembali | blanjaan",19],[28,"kadang | ska | war | akukadang | ahir",18],[29,"kerja | bobot | pemerintaaaahh | boss | ngangur",18],[30,"online | beli | laku | barang | pasar",17],[31,"paham | ok | setuju | gituh | begituu",16],[32,"iy | me | like | aiih | iyee",16],[33,"kalimantan | pendeta | marcel | presenternya | gasii",16],[34,"kasih | akubmalah | kisah | itungn | bintang",14],[35,"indonesia | korupsi | pos | urus | konoha",14],[36,"samaa | indrii | mila | rasain | sariii",14],[37,"gin | panas | harusya | hangus | gebrak",13],[38,"gas | bensin | mn | tera | ngasik",13],[39,"tertawa | lucu | apakabar | kaarenna | ngebuletin",13],[40,"suka | sen | kurir | lebihin | daerah",11],[41,"masak | kelas | cook | jm | kakberapa",10]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[174,106,86,67,52,49,42,42,42,39,38,36,35,34,34,32,30,29,29,26,25,24,24,22,20,20,20,19,18,18,17,16,16,16,14,14,14,13,13,13,11,10],"sizemode":"area","sizeref":0.10875,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[12.443122,3.2194474,12.868263,17.947948,14.319475,-6.4894485,-15.008539,2.0390863,-14.889404,1.529275,-6.052617,2.8694851,14.04077,1.1363162,1.4631115,2.9633772,3.1685941,17.948153,-6.246423,-5.6716485,2.5895371,-5.9871364,12.185693,12.35595,2.9392085,1.9374703,-6.466111,-6.014572,-14.802507,1.6002746,14.081631,-6.111932,2.922591,1.2816441,-5.790995,0.95212734,2.1249716,2.7986383,1.9244813,-15.160691,13.085874,3.0682142],"xaxis":"x","y":[-7.746877,6.8875155,-7.9217076,5.54369,-5.193817,-3.5762877,4.3923135,-5.6056867,4.5116353,6.496386,18.355782,6.997288,-5.4699364,6.3442874,-6.111574,5.0603585,5.9937925,5.543665,18.161886,-4.1479964,6.353884,-4.4012594,-7.9445553,-7.467092,5.8100877,-5.706751,-3.6159503,18.393776,4.5985394,-5.989856,-5.43035,-3.9162028,7.2656484,6.687465,-4.220922,6.1982155,6.4725084,4.885305,-5.72809,4.240009,-7.9776144,5.3 ...

# %%
topic_model2.visualize_barchart(top_n_topics=6)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="09dad3bd-97cd-4889-827b-df8b3c6e5a06" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("09dad3bd-97cd-4889-827b-df8b3c6e5a06")) {                    Plotly.newPlot(                        "09dad3bd-97cd-4889-827b-df8b3c6e5a06",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.024202256374414827,0.028193422275191077,0.044208560779810016,0.05325791102276612,0.05977225695599023],"y":["biaya  ","harga  ","mahal  ","uang  ","bayar  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.00001,0.00001,0.00001,0.00001,0.00001],"y":["  ","  ","  ","  ","  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.028423507674115858,0.030953737692671776,0.03659660960880141,0.043827520946773724,0.049077735620452624],"y":["lebihin  ","paket  ","gaji  ","bayar  ","kurir  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.046873307044314284,0.05691928352426556,0.1944993350928267,0.1956940105132821,0.22603135358542514],"y":["bolak  ","manaa  ","asmara  ","gen  ","trailer  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.05135085821038301,0.12097139538552758,0.12505074276805456,0.1329948661898561,0.14631480890468196],"y":["ad  ","toko  ","shopee  ","jual  ","vip  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.09111318226507356,0.09701062929809913,0.09701062929809913,0.13311541525373724,0.13850498927342153],"y":["segitu  ","sukses  ","nanggung  ","sekolah  ","semangat  "],"type":"bar","xaxis":"x6","yaxis":"y6"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale ...

# %% [markdown]
# ### negatif

# %%
text_neg = df_text[df_text['label'] == 3]

# %%
texts3 = text_neg['stemmed_text']
texts3
# Out:
# 0
# 7                     sibuk pemerintah urus
# 8                                      atur
# 9           urus allah gamau rakyat bahagia
# 10                           diurusin umpat
#                        ...
# 5486    puspita rusak bahagia ja pemerintah
# 5487               dah alih pasar berangkat
# 5489                  gmv turun tambah atur
# 5490                               atur ini
# 5491                      pemerintah gebrak
# Name: stemmed_text, Length: 3049, dtype: object

# %%
texts = texts3.astype(str).tolist()

# %%
# Inisialisasi model UMAP dengan random_state
umap_model = UMAP(n_neighbors=15,
                  n_components=5,
                  min_dist=0.0,
                  metric='cosine',
                  random_state=42)

# Inisialisasi model clustering HDBSCAN dengan random_state
hdbscan_model = HDBSCAN(min_cluster_size=10,
                        metric='euclidean',
                        cluster_selection_method='eom',
                        prediction_data=True)

# Inisialisasi BERTopic dengan model yang sudah disetel random_state
topic_model3 = BERTopic(
    language="indonesian",
    calculate_probabilities=True,
    umap_model=umap_model,
    hdbscan_model=hdbscan_model,
    verbose=True
)

# Fit model
topics, probs = topic_model3.fit_transform(texts3)

# Tampilkan topik dominan
topic_model3.get_topic_info()
# Out:
# 2025-06-05 06:57:54,613 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/96 [00:00<?, ?it/s]
# 2025-06-05 06:57:59,182 - BERTopic - Embedding - Completed ✓
# 2025-06-05 06:57:59,183 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-06-05 06:58:14,421 - BERTopic - Dimensionality - Completed ✓
# 2025-06-05 06:58:14,422 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2025-06-05 06:58:15,077 - BERTopic - Cluster - Completed ✓
# 2025-06-05 06:58:15,082 - BERTopic - Representation - Fine-tuning topics using representation models.
# 2025-06-05 06:58:15,145 - BERTopic - Representation - Completed ✓
#     Topic  Count                                   Name  \
# 0      -1    756         -1_pemerintah_atur_rakyat_biar
# 1       0    303             0_online_offline_jual_beli
# 2       1    269               1_kurir_paket_gaji_beban
# 3       2     65                          2_umur_kota__
# 4       3     62     3_pemerintah_campur_politik_riweuh
# ..    ...    ...                                    ...
# 60     59     12          59_perintah_sgitu_jelas_ekang
# 61     60     11             60_atur_efektif_egk_rebyek
# 62     61     11  61_hadeh_hadeuh_hadehhhh_hadeeeehhhyg
# 63     62     11         62_miskin_sulit_miskinin_adaaj
# 64     63     11   63_bulan_cekoutnya_bearti_bulanankuu
#
#                                        Representation  \
# 0   [pemerintah, atur, rakyat, biar, campur, masya...
# 1   [online, offline, jual, beli, sepi, toko, male...
# 2   [kurir, paket, gaji, beban, kasi, nganggur, ke...
# 3                        [umur, kota, , , , , , , , ]
# 4   [pemerintah, campur, politik, riweuh, oknum, b...
# ..                                                ...
# 60  [perintah, sgitu, jelas, ekang, prabowo, koq, ...
# 61       [atur, efektif, egk, rebyek, tros, , , , , ]
# 62  [hadeh, hadeuh, hadehhhh, hadeeeehhhyg, hadohh...
# 63  [miskin, sulit, miskinin, adaaj, pemerintahhh,...
# 64  [bulan, cekoutnya, bearti, bulanankuu, bari, a...
#
#                                   Representative_Docs
# 0   [pemerintah emng liat rakyat senang dikit biki...
# 1                [beli online, beli online, online l]
# 2   [kurir kerja, beban kurir kurir senang paket k...
# 3                                      [, kota, umur]
# 4   [urus pemerintah, pemerintah urus, pemerintah ...
# ..                                                ...
# 60          [kerja perintah, urus perintah, perintah]
# 61                                 [atur, atur, atur]
# 62                  [hadeh serba salah, hadeh, hadeh]
# 63         [miskin, miskin, pemerintah miskin miskin]
# 64                        [bulan, bulan, bulan bulan]
#
# [65 rows x 5 columns]

# %%
Q =  topic_model3.get_topic_info()
Q.head(10)
# Out:
#    Topic  Count                                Name  \
# 0     -1    756      -1_pemerintah_atur_rakyat_biar
# 1      0    303          0_online_offline_jual_beli
# 2      1    269            1_kurir_paket_gaji_beban
# 3      2     65                       2_umur_kota__
# 4      3     62  3_pemerintah_campur_politik_riweuh
# 5      4     62        4_indonesia_papua_aneh_timur
# 6      5     62       5_banjir_kakean_sulawesi_atur
# 7      6     60             6_kerja_lapang_tri_biar
# 8      7     60            7_korupsi_korup_urus_noh
# 9      8     59           8_berantas_tim_belah_nama
#
#                                       Representation  \
# 0  [pemerintah, atur, rakyat, biar, campur, masya...
# 1  [online, offline, jual, beli, sepi, toko, male...
# 2  [kurir, paket, gaji, beban, kasi, nganggur, ke...
# 3                       [umur, kota, , , , , , , , ]
# 4  [pemerintah, campur, politik, riweuh, oknum, b...
# 5  [indonesia, papua, aneh, timur, ribu, cemas, t...
# 6  [banjir, kakean, sulawesi, atur, brantas, judo...
# 7  [kerja, lapang, tri, biar, urus, da, dikitngas...
# 8  [korupsi, korup, urus, noh, gilir, sulit, tu, ...
# 9  [berantas, tim, belah, nama, mkanya, ngurus, g...
#
#                                  Representative_Docs
# 0  [pemerintah emng liat rakyat senang dikit biki...
# 1               [beli online, beli online, online l]
# 2  [kurir kerja, beban kurir kurir senang paket k...
# 3                                     [, kota, umur]
# 4  [urus pemerintah, pemerintah urus, pemerintah ...
# 5   [indonesia indonesia jawa, indonesia, indonesia]
# 6  [kakean atur, mikir ngatasi banjir sayung dema...
# 7                              [kerja, kerja, kerja]
# 8         [korupsi urus, urus korupsi, korupsi urus]
# 9  [maklum ngurus judol sanggup ngurus gampang ga...

# %%
topic_model3.visualize_topics().show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="37112ae9-fd0b-4e78-b077-3b2084935850" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("37112ae9-fd0b-4e78-b077-3b2084935850")) {                    Plotly.newPlot(                        "37112ae9-fd0b-4e78-b077-3b2084935850",                        [{"customdata":[[0,"online | offline | jual | beli | sepi",303],[1,"kurir | paket | gaji | beban | kasi",269],[2,"umur | kota |  |  | ",65],[3,"pemerintah | campur | politik | riweuh | oknum",62],[4,"indonesia | papua | aneh | timur | ribu",62],[5,"banjir | kakean | sulawesi | atur | brantas",62],[6,"kerja | lapang | tri | biar | urus",60],[7,"korupsi | korup | urus | noh | gilir",60],[8,"berantas | tim | belah | nama | mkanya",59],[9,"uang | pke | sndri | ekonomi | cari",59],[10,"tertawa | lucu | senyum | bijak | udhlah",57],[11,"mahal | harga | barang | kalimantan | beli",49],[12,"jual | pasar | suruh | ramai | sepi",40],[13,"kerja | pemerintah | mslh | ngak | beginitentu",40],[14,"kominfo | ywes | sehat | kudu | judol",39],[15,"rakyat | senang | nyusahin | bahagia | sejahtera",38],[16,"elehhh | yaaahhh | alah | ah | aelaaaahhh",37],[17,"konoha | ngapain | duga | untran | pemerintah",37],[18,"judol | urus | tikus | an | woi",35],[19,"uang | pemerintah | cari | cepet | masuk",35],[20,"gin | adem | kaya | tenang | gilir",31],[21,"bangettt | akal | bisa | yaudah | gitudri",31],[22,"gawat | kesal | capek | benci | gwendeng",30],[23,"batas | langkah | siehh | habis | bntr",30],[24,"nyusahin | buruk | pemerintah | rakyat | blunder",29],[25,"bayar | pas | biaya | dtmpt | taro",28],[26,"et | demo | solusi | bgitu | inih",27],[27,"shopee | toko | plus | vip | buka",26],[28,"susah | rakyat | senang | hoh | motivasi",25],[29,"kalimantan | nyusahin | laku | up | pahlawan",24],[30,"susah | stres | sulit | stresss | gi",23],[31,"korupsi | sepele | gin | kelas | fokus",23],[32,"sulawesi | gabisa | konoha | agrid | melosot",22],[33,"elahhh | konohaaaa | da | hahah | sihhh",22],[34,"barang | beli | apa | belanja | dongggg",22],[35,"kerja | pemerintah | dasar | urus | ",21],[36,"susah | hobi | rakyat | beban | pemerintah",20],[37,"pemerintah | an |  |  | ",20],[38,"gmn | nasib | produk | impor | waah",18],[39,"aneh | otak | digital | gila | pemerintah",18],[40,"akun | ganti | hbs | akunn | pakenya",17],[41,"affiliate | join | mula | bantu | rintis",17],[42,"sibuk | nyusahno | sibukk | sibuke | remeh",17],[43,"usut | neh | dahhh | noh | repot",16],[44,"sedih | susah | swatch | huaaaa | menangiss",16],[45,"gin | aspek | smua | kaya | konoha",16],[46,"pajak | oksigen | cie | efisiensi | hirup",16],[47,"serah | sabo | syedih | tersrah | heleh",16],[48,"umpat | rang | urus |  | ",15],[49,"senang | tunjang | suka | bahagia | rakyat",15],[50,"aneh | awuuuu | nyajadi | ngakak | lahir",15],[51,"anggur | nambah | angka | solusi | kdepannya",14],[52,"ekspedisi | shopee | kampung | gua | beda",14],[53,"heran | serius | dehh | bangett | bingung",13],[54,"bagus | irit | biar | filter | wkwkkw",13],[55,"pindah | zaman | maju | ikutin | terusin",13],[56,"aduh | umpat |  |  | ",12],[57,"pulau | jawa | luar | peduli | keluh",12],[58,"allah | semangat | guru | sejahteranyaaa | apasii",12],[59,"perintah | sgitu | jelas | ekang | prabowo",12],[60,"atur | efektif | egk | rebyek | tros",11],[61,"hadeh | hadeuh | hadehhhh | hadeeeehhhyg | hadohhhhhh",11],[62,"miskin | sulit | miskinin | adaaj | pemerintahhh",11],[63,"bulan | cekoutnya | bearti | bulanankuu | bari",11]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[303,269,65,62,62,62,60,60,59,59,57,49,40,40,39,38,37,37, ...

# %%
topic_model3.visualize_barchart(top_n_topics=5)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c38ca365-73b8-4e4d-9f29-043e3e5a6d15" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c38ca365-73b8-4e4d-9f29-043e3e5a6d15")) {                    Plotly.newPlot(                        "c38ca365-73b8-4e4d-9f29-043e3e5a6d15",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.020450692618335185,0.022282139372498677,0.02458719593190314,0.03209622029688624,0.07335043444943315],"y":["sepi  ","beli  ","jual  ","offline  ","online  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.020328216646102425,0.030220763495451247,0.03737473702174238,0.04540011907533048,0.06237976224551098],"y":["kasi  ","beban  ","gaji  ","paket  ","kurir  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.00001,0.00001,0.00001,1.9991003508345992,2.140642532436175],"y":["  ","  ","  ","kota  ","umur  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.04391061604997282,0.048021858739735586,0.048021858739735586,0.054423690800103265,0.09447001754855758],"y":["oknum  ","riweuh  ","politik  ","campur  ","pemerintah  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.032983304641360886,0.036111151121487904,0.037420077205884465,0.0396058720874012,0.27129555974266234],"y":["ribu  ","timur  ","aneh  ","papua  ","indonesia  "],"type":"bar","xaxis":"x5","yaxis":"y5"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.77777 ...

# %% [markdown]
# ## Engagement

# %%
# Buat salinan DataFrame dari kolom relevan
dfp = df[['uniqueId', 'diggCount', 'replyCommentTotal']].copy()

# Hitung engagements (like + komentar)
dfp['engagements'] = dfp[['diggCount', 'replyCommentTotal']].sum(axis=1)

# Ganti nama kolom agar lebih jelas
dfp.rename(columns={'uniqueId': 'username'}, inplace=True)

# Urutkan berdasarkan engagements tertinggi
dfp = dfp.sort_values(by='engagements', ascending=False).reset_index(drop=True)

# Tampilkan 10 teratas
dfp = dfp[['username', 'engagements']]
dfp.head(10)
# Out:
#              username  engagements
# 0      nabillaaptriii      47998.0
# 1         ooribeefsnn      27199.0
# 2          dioooimida      16923.0
# 3           dindakest      14149.0
# 4  user71542340382576      14103.0
# 5          rifky_m1bb      12125.0
# 6           itadwi123      12052.0
# 7        n7r1pl3.__.n       7851.0
# 8            sukamiev       6664.0
# 9             clarzha       4705.0

# %%
import matplotlib.pyplot as plt

# Fungsi untuk menampilkan nilai absolut (jumlah engagements)
def absolute_value(val):
    total = sum(dfp.head(7)['engagements'])
    return f"{int(round(val * total / 100))}"

# Ambil 7 besar username dan engagement
top7 = dfp.head(7)

# Plot pie chart
plt.figure(figsize=(6, 6))
plt.pie(
    top7['engagements'],
    labels=top7['username'],
    autopct=absolute_value,
    startangle=0,
    wedgeprops={'linewidth': 2, 'edgecolor': 'white'}
)

# Buat pie chart jadi bentuk donut
my_circle = plt.Circle((0, 0), 0.7, color='white')
p = plt.gcf()
p.gca().add_artist(my_circle)

# Judul grafik
plt.title('Jumlah Engagement dari Masing-Masing Pemengaruh')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Kesimpulan

# %% [markdown]
# Kebijakan pengaturan diskon ongkir melalui Permen Komdigi No. 8 Tahun 2025 memicu reaksi publik yang mayoritas negatif (55%), karena adanya kekhawatiran bahwa biaya belanja online akan naik dan pendapatan kurir terdampak. Puncak perbincangan terjadi pada 20 Mei 2025, menunjukkan tingginya atensi publik dalam waktu singkat.
#
# Meskipun sebagian kecil mendukung kebijakan ini sebagai peluang untuk toko offline kembali berjaya, sentimen negatif yang mendominasi dan kritik terhadap pemerintah mengindikasikan adanya kesenjangan antara tujuan kebijakan dan pemahaman masyarakat.

# %% [markdown]
# # Rekomendasi

# %% [markdown]
# * **Meningkatkan Kejelasan Tujuan Kebijakan**: Publik tampaknya membutuhkan pemahaman yang lebih baik tentang alasan di balik kebijakan ini. Penjelasan yang sederhana dan mudah dipahami dapat membantu mengurangi penolakan.
# * **Memberikan Dukungan kepada Pekerja Logistik**: Ada kekhawatiran bahwa kebijakan ini memengaruhi mata pencaharian pekerja logistik. Pemerintah bisa mempertimbangkan bantuan atau insentif untuk menjaga stabilitas ekonomi mereka.
# * **Mendorong Aktivitas Ekonomi Lokal**: Banyak yang melihat manfaat dari belanja di pasar tradisional atau toko offline. Inisiatif untuk memperkuat ekonomi lokal bisa menjadi solusi yang diterima masyarakat.
# * **Menyediakan Alternatif untuk Konsumen**: Sebagian masyarakat mencari cara untuk tetap mendapatkan pengiriman terjangkau, seperti melalui program keanggotaan e-commerce. Pemerintah dapat bekerja sama dengan platform digital untuk menawarkan opsi serupa.
# * **Merespons Kritik dengan Dialog**: Ada ketidakpuasan terhadap cara kebijakan ini diterapkan. Membuka ruang diskusi dengan masyarakat dapat membantu meredam ketidaksetujuan dan membangun kepercayaan.
# * **Memantau Dampak Secara Berkala**: Reaksi masyarakat tampak berubah seiring waktu. Dengan terus memantau dan menyesuaikan langkah, pemerintah dapat lebih responsif terhadap kebutuhan masyarakat.
